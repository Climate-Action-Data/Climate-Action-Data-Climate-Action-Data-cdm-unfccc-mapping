# %%
import pandas as pd

import numpy as np

from datetime import datetime

import requests
from requests.exceptions import RequestException
import json

from datetime import datetime

# %% [markdown]
# IMPORT RELEVANT CSV FILE

# %%
# Main CDM Registry project datasource from Database PA POA
df_activities= pd.read_excel('./input/CDM-Activities-November.xlsx')

# Country and geographic identifier file for easier mapping
df_country_code = pd.read_excel('./input/cdm-country-code.xlsx')


# Countries in CADTrust, to check with the mismatch from UNFCCC in later data processing
df_cadt_country = pd.read_excel("./input/CADTrust_Country.xlsx")

# LOAD UNEP file for PDD mapping
df_unep = pd.read_excel("./input/cdm-pipeline.xlsx")

# %% [markdown]
# INITIAL CLEANUP

# %%
# FILL CDM project reference number NAN value to 0, since there are almost 3000 of them

df_activities['CDM project reference number'] = df_activities['CDM project reference number'].fillna(0).astype(int)


# Check projects with more than one host countries/ "List of host countries (ISO 2)"
more_countries = df_activities[df_activities["List of host countries (ISO 2)"].str.len() > 2]

# Create excel files for projects with more than one countries/ "List of host countries (ISO 2)",
more_countries.to_excel("./output/CDM_projects_many_countries.xlsx")

# Map to CAD Trust based on the first country in the column
df_activities["List of host countries (ISO 2)"] = df_activities["List of host countries (ISO 2)"].str[:2]

# Apply geographic identifier that is suitable for CAD Trust mapping
df_country_code['geographicIdentifier'] = df_country_code.apply(
    lambda row: "{\"latitude\":" + str(row["latitude"]) + ",\"longitude\":" + str(row["longitude"]) + "}", axis=1
)

# Key Value mapping of PDD Consultant for CAD Trust projectDeveloper
pdd_developer_map = df_unep.set_index('Unique project ID')['PDD Consultant'].to_dict()

# Key Value mapping of reference number to unique identifier that will be useful for ISSUANCES and UNITS
id_to_id = df_activities.set_index('CDM project reference number')['Unique project identifier (traceable with Google)'].to_dict()

#Key Value mapping Country Code to CAD Trust Country Field
country_name_map = df_country_code.set_index('country')['cadtcountry'].to_dict()


#Key Value mapping Country Code to Geography Map
geography_map = df_country_code.set_index('name')['geographicIdentifier'].to_dict()

#Key Value mapping verification report date
verification_report_date_map = df_activities.set_index('Unique project identifier (traceable with Google)')['Start of first crediting period'].to_dict()




# Map to status fields from CDM to CAD Trust Project Status Picklist Value
project_status_map = {
    "Registered": "Registered",
    "Rejected": "Withdrawn",
    "Withdrawn":"Withdrawn",
    "WithdrawnBeforePublication": "Withdrawn",
    "Withdrawn Before Publication": "Withdrawn",
    "Deregistered": "De-registered",
    "Pending Publication": "Authorized",
    "Provisional": "Validated",
    "Validation Replaced": "Validated",
    "Requesting Registration": "Listed",
    "Validation Public": "Validated",
    "Validation Terminated": "Withdrawn",
    "NA":"Listed",
    "":"Listed",
    np.nan: "Listed"  # Handling actual NaN values
}
# Map from sector code number to it's description
sector_code_map = {
  "1": 'Energy industries (renewable - / non-renewable sources)',
  "2": 'Energy distribution',
  "3": 'Energy demand',
  "4": 'Manufacturing industries',
  "5": 'Chemical industries',
  "6": 'Construction',
  "7": 'Transport',
  "8": 'Mining/mineral production',
  "9": 'Metal production',
  "10": 'Fugitive emissions from fuels (solid, oil and gas)',
  "11": 'Fugitive emissions from production and consumption of halocarbons and sulphur hexafluoride',
  "12": 'Solvent use',
  "13": 'Waste handling and disposal',
  "14": 'Afforestation and reforestation',
  "15": 'Agriculture'
}


# basic cleanup
def fillna_by_dtype(df):
    for column in df.columns:
        if pd.api.types.is_numeric_dtype(df[column]):  # Check if the column is numeric
            df[column] = df[column].fillna(0)
        elif pd.api.types.is_object_dtype(df[column]):  # Check if the column is of object type (e.g., strings)
            df[column] = df[column].fillna('NA')
        elif pd.api.types.is_datetime64_any_dtype(df[column]):  # Check if the column is datetime
            df[column] = df[column].fillna(pd.Timestamp.min)
    return df

    


set_cadt_country = set(df_cadt_country['Country'])
set_country_code = set(df_country_code['name'])

# Find non-matching elements
print(set_cadt_country - set_country_code)
print(set_country_code - set_cadt_country)
# Out:
# {'Equatorial New Guinea', 'Sao Tome and Principe', 'Republic of Korea', 'Myanmar', 'Guinea Bissau', 'Bosnia and  Herzegovina', 'South Sudan', "Cote d'Ivoire", 'Brunei Darussalam', 'State of Palestine', 'United Republic of Tanzania', 'Antigua and Barduba', "Democratic People's Republic of Korea", 'United States of America', 'Congo', 'The Former Yugoslav Republic of Macedonia', 'Domincan Republic', 'Viet Nam', "Lao People's Democratic Republic", 'Cabo Verde', 'European Union', 'Russian Federation', 'Democratic Republic of Congo'}
# {'Turks and Caicos Islands', 'Kosovo', 'New Caledonia', 'Svalbard and Jan Mayen', 'Gambia', 'American Samoa', 'Netherlands Antilles', 'Mayotte', 'Guernsey', 'Martinique', 'North Korea', 'French Polynesia', 'Christmas Island', 'Cook Islands', 'Nigeria', 'Sierra Leone', 'Russia', 'Guam', 'Montserrat', 'Turkmenistan', 'Brunei', 'Vatican City', 'Gaza Strip', 'Uzbekistan', 'Laos', 'Antigua and Barbuda', 'Iraq', 'South Georgia and the South Sandwich Islands', 'French Southern Territories', 'British Virgin Islands', 'Anguilla', 'Bermuda', 'Dominican Republic', 'Saint Helena', 'Macau', 'Syria', 'Niue', 'Kyrgyzstan', 'British Indian Ocean Territory', 'United States', 'Cape Verde', 'Vietnam', 'Puerto Rico', 'Réunion', 'Equatorial Guinea', 'Tanzania', 'Falkland Islands [Islas Malvinas]', 'Pitcairn Islands', 'Macedonia [FYROM]', 'Norfolk Island', 'Wallis and Futuna', 'Malawi', 'Guadeloupe', 'Cayman Islands', 'South Korea', 'Aruba', 'French Guiana', 'Seychelles', 'Nicaragua', 'Myanmar [Burma]', 'Tokelau', 'Togo', 'Bosnia and Herzegovina', 'Palestinian Territories', 'Yemen', 'Gibraltar', 'Guinea-Bissau', 'Congo [Republic]', 'Western Sahara', 'Ecuador', 'Heard Island and McDonald Islands', "Côte d'Ivoire", 'U.S. Virgin Islands', 'Congo [DRC]', 'Saint Pierre and Miquelon', 'Greenland', 'Moldova', 'Taiwan', 'U.S. Minor Outlying Islands', 'Armenia', 'Cocos [Keeling] Islands', 'Faroe Islands', 'Kazakhstan', 'Zambia', 'Jersey', 'Northern Mariana Islands', 'São Tomé and Príncipe', 'Bouvet Island', 'Isle of Man', 'Hong Kong', 'Antarctica'}

# %%
# Rename the df column to match CADTrust field

rename_columns  = {
  "Unique project identifier (traceable with Google)": "originProjectId",
  "Registration project title": "projectName",
  "Type of CDM project: PA/PoA": "program",
  "Sectoral scope number(s)": "sector",
  "Project type (UNEP DTU)": "projectType",
  "Website project status": "projectStatus",
  "Methodologies used at registration": "methodology",
  "DOE": "validationBody",
  "Start of validation": "validationDate",
  "Country subregion":"inCountryRegion",
  "List of host countries (ISO 2)": "country",

  'Start of first crediting period':'creditingPeriodStart',
  'End of first crediting period':'creditingPeriodEnd',
  'Total CERs issued': 'unitCount'
}

# "creditingPeriodStart":"2022-02-04T00:00:00.000Z",
#         "creditingPeriodEnd":"2022-03-04T00:00:00.000Z",
#         "unitCount":100,

df_project = df_activities[rename_columns.keys()].rename(columns=rename_columns)

print("Data types of specific columns:")
print("creditingPeriodStart:", df_project['creditingPeriodStart'].dtype)
print("creditingPeriodEnd:", df_project['creditingPeriodEnd'].dtype)
print("unitCount:", df_project['unitCount'].dtype)

df_project['creditingPeriodStart'] = pd.to_datetime(df_project['creditingPeriodStart'], errors='coerce')
df_project['creditingPeriodEnd'] = pd.to_datetime(df_project['creditingPeriodEnd'], errors='coerce')

df_project['unitCount'] = df_project['unitCount'].replace("-", 0).fillna(0)

df_project['estimations'] = df_project.apply(lambda row: [{
    "creditingPeriodStart": row['creditingPeriodStart'].strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z' if pd.notnull(row['creditingPeriodStart']) else None,
    "creditingPeriodEnd": row['creditingPeriodEnd'].strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z' if pd.notnull(row['creditingPeriodEnd']) else None,
    "unitCount": row['unitCount']
}], axis=1)

df_project.drop(columns=['creditingPeriodStart', 'creditingPeriodEnd', 'unitCount'], inplace=True)

print(df_project.columns)

# Adding other relevant values to CAD Trust field
df_project["registryOfOrigin"]= "CDM Registry"
df_project["currentRegistry"]= "CDM Registry"
df_project['unitMetric'] = 'tCO2e'
df_project['methodology'] = "CDM - " + df_project['methodology']
df_project['projectId'] = df_project['originProjectId']
df_project['projectLink'] = 'https://cdm.unfccc.int/Projects/Validation/DB/' +df_project['projectId']+"/view.html"
df_project['coveredByNDC'] = "Unknown"
df_project['projectStatusDate'] = datetime.now().strftime('%Y-%m-%d')

# Map the countries
df_project['country'] = df_project['country'].map(country_name_map)
df_project['sector'] = df_project['sector'].map(sector_code_map)
df_project['projectDeveloper'] = df_project['projectId'].map(pdd_developer_map)
df_project["geographicIdentifier"]= df_project['country'].map(geography_map)
df_project['description'] = df_project['projectName']
df_project['ndcInformation'] = "NA"

# Implement the fillna function created earlier
df_project = fillna_by_dtype(df_project)
df_project["projectStatus"]= df_project['projectStatus'].map(project_status_map)


projID_to_country = df_project.set_index('projectId')['country'].to_dict()



# Output to check the new DataFrame
df_project.to_excel("./output/CDM-Projects-mapped.xlsx")

# df_project['country'].head(10)


df_project
# Out:
# Data types of specific columns:
# creditingPeriodStart: object
# creditingPeriodEnd: object
# unitCount: int64
# Index(['originProjectId', 'projectName', 'program', 'sector', 'projectType',
#        'projectStatus', 'methodology', 'validationBody', 'validationDate',
#        'inCountryRegion', 'country', 'estimations'],
#       dtype='object')
#                       originProjectId  \
# 0                               AuxID
# 1      LJ80OQZR2JVOLTZZX4Y0EGB1N18AVO
# 2      SQA16OAS75TKWYZTTKK7G1LO0O8CMU
# 3      HG20LFVJPFURJJ4M6E6MS07HTOZTR4
# 4      V3ZBEVSXGFNT31E2CECR2NYE93FW5L
# ...                               ...
# 13168  QJD9XJ5HBYCRZR6YV9ELX4WLEC5BJ1
# 13169  4FFA579VM5UA6G3BHJYNRH5Q5Q6S6W
# 13170  R33WIRKXKCNOCGHYW84XRF3SJ0KKNI
# 13171  GT5ME4TC32NKLA6A22ZBR00FYBC54N
# 13172  25QFSD4M35AR2Y55695EBINI56CCNC
#
#                                              projectName program  \
# 0      Project for GHG emission reduction by thermal ...      PA
# 1                     HFC Decomposition Project in Ulsan      PA
# 2        Brazil NovaGerar Landfill Gas to Energy Project      PA
# 3                     La Esperanza Hydroelectric Project      PA
# 4      Project for GHG Emission Reduction by Thermal ...      PA
# ...                                                  ...     ...
# 13168  Reduction in steam consumption through revampi...      PA
# 13169  Usina Petribu Renewable Generation with Sugarc...      PA
# 13170  Power generation from renewable sources  Aiur...      PA
# 13171           Roaring 40s Wind Farms  Private Limited.      PA
# 13172  Energy efficiency measure through dry de-dusti...      PA
#
#                                                   sector     projectType  \
# 0      Fugitive emissions from production and consump...            HFCs
# 1      Fugitive emissions from production and consump...            HFCs
# 2                            Waste handling and disposal    Landfill gas
# 3      Energy industries (renewable - / non-renewable...           Hydro
# 4      Fugitive emissions from production and consump...            HFCs
# ...                                                  ...             ...
# 13168                                      Energy demand     EE Industry
# 13169  Energy industries (renewable - / non-renewable...  Biomass Energy
# 13170  Energy industries (renewable - / non-renewable...           Hydro
# 13171  Energy industries (renewable - / non-renewable...            Wind
# 13172                                                 NA     EE Industry
#
#       projectStatus      methodology  \
# 0        Registered     CDM - AM0001
# 1        Registered     CDM - AM0001
# 2        Registered     CDM - AM0003
# 3        Registered   CDM - AMS-I.D.
# 4        Registered     CDM - AM0001
# ...             ...              ...
# 13168     Withdrawn     CDM - AM0018
# 13169     Withdrawn    CDM - ACM0006
# 13170     Withdrawn    CDM - ACM0002
# 13171     Validated    CDM - ACM0002
# 13172     Withdrawn  CDM - AMS-II.D.
#
#                                         validationBody       validationDate  \
# 0                     SGS United Kingdom Limited (SGS)  2003-12-01 00:00:00
# 1           Japan Quality Assurance Organisation (JQA)  2003-12-11 00:00:00
# 2                              Det Norske Veritas- CUK  2004-04-05 00:00:00
# 3                              Det Norske Veritas- CUK  2004-07-04 00:00:00
# 4           Japan Quality Assurance Organisation (JQA)  2005-12-06 00:00:00
# ...                                                ...                  ...
# 13168  Bureau Veritas Certification Holding SAS (BVCH)  2007-03-21 00:00:00
# 13169                 SGS United Kingdom Limited (SGS)  2006-04-12 00:00:00
# 13170                      RINA Services S.p.A. (RINA)  2009-05-08 00:00:00
# 13171                          Det Norske Veritas- CUK  2007-06-07 00:00:00
# 13172                 SGS United Kingdom Limited (SGS)                39317
#
#        inCountryRegion  ... currentRegistry unitMetric  \
# 0        Southern Asia  ...    CDM Registry      tCO2e
# 1         Eastern Asia  ...    CDM Registry      tCO2e
# 2        South America  ...    CDM Registry      tCO2e
# 3      Central America  ...    CDM Registry      tCO2e
# 4         Eastern Asia  ...    CDM Registry      tCO2e
# ...                ...  ...             ...        ...
# 13168    Southern Asia  ...    CDM Registry      tCO2e
# 13169    South America  ...    CDM Registry      tCO2e
# 13170    South America  ...    CDM Registry      tCO2e
# 13171    Southern Asia  ...    CDM Registry      tCO2e
# 13172    Southern Asia  ...    CDM Registry      tCO2e
#
#                             projectId  \
# 0                               AuxID
# 1      LJ80OQZR2JVOLTZZX4Y0EGB1N18AVO
# 2      SQA16OAS75TKWYZTTKK7G1LO0O8CMU
# 3      HG20LFVJPFURJJ4M6E6MS07HTOZTR4
# 4      V3ZBEVSXGFNT31E2CECR2NYE93FW5L
# ...                               ...
# 13168  QJD9XJ5HBYCRZR6YV9ELX4WLEC5BJ1
# 13169  4FFA579VM5UA6G3BHJYNRH5Q5Q6S6W
# 13170  R33WIRKXKCNOCGHYW84XRF3SJ0KKNI
# 13171  GT5ME4TC32NKLA6A22ZBR00FYBC54N
# 13172  25QFSD4M35AR2Y55695EBINI56CCNC
#
#                                              projectLink coveredByNDC  \
# 0      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 1      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 2      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 3      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 4      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# ...                                                  ...          ...
# 13168  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13169  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13170  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13171  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13172  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
#
#       projectStatusDate                   projectDeveloper  \
# 0            2024-04-01             PricewaterhouseCoopers
# 1            2024-04-01                    Climate Experts
# 2            2024-04-01                      EcoSecurities
# 3            2024-04-01            WB-CF, 2E Carbon Access
# 4            2024-04-01                   WB-CF, SEPA FECO
# ...                 ...                                ...
# 13168        2024-04-01  Rashtriya Chemicals & Fertilizers
# 13169        2024-04-01                       MaxAmbiental
# 13170        2024-04-01                          Waycarbon
# 13171        2024-04-01                  Satia Paper Mills
# 13172        2024-04-01               Jindal Steel & Power
#
#                                 geographicIdentifier  \
# 0        {"latitude":20.593684,"longitude":78.96288}
# 1                                                 NA
# 2      {"latitude":-14.235004,"longitude":-51.92528}
# 3      {"latitude":15.199999,"longitude":-86.241905}
# 4       {"latitude":35.86166,"longitude":104.195397}
# ...                                              ...
# 13168    {"latitude":20.593684,"longitude":78.96288}
# 13169  {"latitude":-14.235004,"longitude":-51.92528}
# 13170  {"latitude":-14.235004,"longitude":-51.92528}
# 13171    {"latitude":20.593684,"longitude":78.96288}
# 13172    {"latitude":20.593684,"longitude":78.96288}
#
#                                              description ndcInformation
# 0      Project for GHG emission reduction by thermal ...             NA
# 1                     HFC Decomposition Project in Ulsan             NA
# 2        Brazil NovaGerar Landfill Gas to Energy Project             NA
# 3                     La Esperanza Hydroelectric Project             NA
# 4      Project for GHG Emission Reduction by Thermal ...             NA
# ...                                                  ...            ...
# 13168  Reduction in steam consumption through revampi...             NA
# 13169  Usina Petribu Renewable Generation with Sugarc...             NA
# 13170  Power generation from renewable sources  Aiur...             NA
# 13171           Roaring 40s Wind Farms  Private Limited.             NA
# 13172  Energy efficiency measure through dry de-dusti...             NA
#
# [13173 rows x 23 columns]

# %% [markdown]
# Findings After Failing to Push data to Chia staging API

# %%
# Yemen and Cape Verde not in CAD Trust picklist. This require approval from technical committee otherwise we cant push the data
# 5 projects in total
df_project_yemen_cape_verde = df_project[(df_project['country'] == 'Yemen') | (df_project['country'] == 'Cape Verde')]
# df_with_nan_cdmID has One nan value which is project CDM 10121 row 8459

df_with_nan_cdmID = df_project[df_project['projectId']=='NA']

# Projects that have projectID, but the rest are not filled properly
df_with_nan_validation_date = df_project[df_project['validationDate']=='NA']

# Telling this issue to unfccc
df_to_inform_UNFCCC_1 = df_activities[df_activities['Unique project identifier (traceable with Google)']
                                        .isna()]

df_to_inform_UNFCCC_2 = df_activities[df_activities['Unique project identifier (traceable with Google)']
                                        .isin(df_with_nan_validation_date['projectId'])]

# Concatenating the two DataFrame into one
df_to_inform_UNFCCC = pd.concat([df_to_inform_UNFCCC_1, df_to_inform_UNFCCC_2])

df_to_inform_UNFCCC.to_excel("./output/Uncleaned_CDM_Projects.xlsx")

# %% [markdown]
# DROP THE ROWS OF DATA MENTIONED ABOVE. AFTER THAT, the API call should be smoothly post all the entire data to CAD Trust chia datalayer local staging mode

# %%
# df_cleaned_project = df_project[~((df_project['country'] == 'Yemen') | (df_project['country'] == 'Cape Verde')| (df_project['country'] == 'Bhutan'))]

# Select rows where projectId is not 'NA'
df_cleaned_project = df_project[df_project['projectId'] != 'NA']


df_cleaned_project = df_cleaned_project[
    ~df_project['country'].isin([ 'Bhutan'])]


# Select rows where validationDate is not 'NA'
df_cleaned_project = df_cleaned_project[df_cleaned_project['validationDate'] != 'NA']

df_cleaned_project.to_excel("./output/cdm_projects_mapped_cleaned.xlsx")
# df_cleaned_project
df_bhutan = df_project[df_project['country'] == 'Bhutan']
df_bhutan

df_cleaned_project
# Out:
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/2822730733.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned_project = df_cleaned_project[
#                       originProjectId  \
# 0                               AuxID
# 1      LJ80OQZR2JVOLTZZX4Y0EGB1N18AVO
# 2      SQA16OAS75TKWYZTTKK7G1LO0O8CMU
# 3      HG20LFVJPFURJJ4M6E6MS07HTOZTR4
# 4      V3ZBEVSXGFNT31E2CECR2NYE93FW5L
# ...                               ...
# 13168  QJD9XJ5HBYCRZR6YV9ELX4WLEC5BJ1
# 13169  4FFA579VM5UA6G3BHJYNRH5Q5Q6S6W
# 13170  R33WIRKXKCNOCGHYW84XRF3SJ0KKNI
# 13171  GT5ME4TC32NKLA6A22ZBR00FYBC54N
# 13172  25QFSD4M35AR2Y55695EBINI56CCNC
#
#                                              projectName program  \
# 0      Project for GHG emission reduction by thermal ...      PA
# 1                     HFC Decomposition Project in Ulsan      PA
# 2        Brazil NovaGerar Landfill Gas to Energy Project      PA
# 3                     La Esperanza Hydroelectric Project      PA
# 4      Project for GHG Emission Reduction by Thermal ...      PA
# ...                                                  ...     ...
# 13168  Reduction in steam consumption through revampi...      PA
# 13169  Usina Petribu Renewable Generation with Sugarc...      PA
# 13170  Power generation from renewable sources  Aiur...      PA
# 13171           Roaring 40s Wind Farms  Private Limited.      PA
# 13172  Energy efficiency measure through dry de-dusti...      PA
#
#                                                   sector     projectType  \
# 0      Fugitive emissions from production and consump...            HFCs
# 1      Fugitive emissions from production and consump...            HFCs
# 2                            Waste handling and disposal    Landfill gas
# 3      Energy industries (renewable - / non-renewable...           Hydro
# 4      Fugitive emissions from production and consump...            HFCs
# ...                                                  ...             ...
# 13168                                      Energy demand     EE Industry
# 13169  Energy industries (renewable - / non-renewable...  Biomass Energy
# 13170  Energy industries (renewable - / non-renewable...           Hydro
# 13171  Energy industries (renewable - / non-renewable...            Wind
# 13172                                                 NA     EE Industry
#
#       projectStatus      methodology  \
# 0        Registered     CDM - AM0001
# 1        Registered     CDM - AM0001
# 2        Registered     CDM - AM0003
# 3        Registered   CDM - AMS-I.D.
# 4        Registered     CDM - AM0001
# ...             ...              ...
# 13168     Withdrawn     CDM - AM0018
# 13169     Withdrawn    CDM - ACM0006
# 13170     Withdrawn    CDM - ACM0002
# 13171     Validated    CDM - ACM0002
# 13172     Withdrawn  CDM - AMS-II.D.
#
#                                         validationBody       validationDate  \
# 0                     SGS United Kingdom Limited (SGS)  2003-12-01 00:00:00
# 1           Japan Quality Assurance Organisation (JQA)  2003-12-11 00:00:00
# 2                              Det Norske Veritas- CUK  2004-04-05 00:00:00
# 3                              Det Norske Veritas- CUK  2004-07-04 00:00:00
# 4           Japan Quality Assurance Organisation (JQA)  2005-12-06 00:00:00
# ...                                                ...                  ...
# 13168  Bureau Veritas Certification Holding SAS (BVCH)  2007-03-21 00:00:00
# 13169                 SGS United Kingdom Limited (SGS)  2006-04-12 00:00:00
# 13170                      RINA Services S.p.A. (RINA)  2009-05-08 00:00:00
# 13171                          Det Norske Veritas- CUK  2007-06-07 00:00:00
# 13172                 SGS United Kingdom Limited (SGS)                39317
#
#        inCountryRegion  ... currentRegistry unitMetric  \
# 0        Southern Asia  ...    CDM Registry      tCO2e
# 1         Eastern Asia  ...    CDM Registry      tCO2e
# 2        South America  ...    CDM Registry      tCO2e
# 3      Central America  ...    CDM Registry      tCO2e
# 4         Eastern Asia  ...    CDM Registry      tCO2e
# ...                ...  ...             ...        ...
# 13168    Southern Asia  ...    CDM Registry      tCO2e
# 13169    South America  ...    CDM Registry      tCO2e
# 13170    South America  ...    CDM Registry      tCO2e
# 13171    Southern Asia  ...    CDM Registry      tCO2e
# 13172    Southern Asia  ...    CDM Registry      tCO2e
#
#                             projectId  \
# 0                               AuxID
# 1      LJ80OQZR2JVOLTZZX4Y0EGB1N18AVO
# 2      SQA16OAS75TKWYZTTKK7G1LO0O8CMU
# 3      HG20LFVJPFURJJ4M6E6MS07HTOZTR4
# 4      V3ZBEVSXGFNT31E2CECR2NYE93FW5L
# ...                               ...
# 13168  QJD9XJ5HBYCRZR6YV9ELX4WLEC5BJ1
# 13169  4FFA579VM5UA6G3BHJYNRH5Q5Q6S6W
# 13170  R33WIRKXKCNOCGHYW84XRF3SJ0KKNI
# 13171  GT5ME4TC32NKLA6A22ZBR00FYBC54N
# 13172  25QFSD4M35AR2Y55695EBINI56CCNC
#
#                                              projectLink coveredByNDC  \
# 0      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 1      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 2      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 3      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 4      https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# ...                                                  ...          ...
# 13168  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13169  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13170  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13171  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
# 13172  https://cdm.unfccc.int/Projects/Validation/DB/...      Unknown
#
#       projectStatusDate                   projectDeveloper  \
# 0            2024-04-01             PricewaterhouseCoopers
# 1            2024-04-01                    Climate Experts
# 2            2024-04-01                      EcoSecurities
# 3            2024-04-01            WB-CF, 2E Carbon Access
# 4            2024-04-01                   WB-CF, SEPA FECO
# ...                 ...                                ...
# 13168        2024-04-01  Rashtriya Chemicals & Fertilizers
# 13169        2024-04-01                       MaxAmbiental
# 13170        2024-04-01                          Waycarbon
# 13171        2024-04-01                  Satia Paper Mills
# 13172        2024-04-01               Jindal Steel & Power
#
#                                 geographicIdentifier  \
# 0        {"latitude":20.593684,"longitude":78.96288}
# 1                                                 NA
# 2      {"latitude":-14.235004,"longitude":-51.92528}
# 3      {"latitude":15.199999,"longitude":-86.241905}
# 4       {"latitude":35.86166,"longitude":104.195397}
# ...                                              ...
# 13168    {"latitude":20.593684,"longitude":78.96288}
# 13169  {"latitude":-14.235004,"longitude":-51.92528}
# 13170  {"latitude":-14.235004,"longitude":-51.92528}
# 13171    {"latitude":20.593684,"longitude":78.96288}
# 13172    {"latitude":20.593684,"longitude":78.96288}
#
#                                              description ndcInformation
# 0      Project for GHG emission reduction by thermal ...             NA
# 1                     HFC Decomposition Project in Ulsan             NA
# 2        Brazil NovaGerar Landfill Gas to Energy Project             NA
# 3                     La Esperanza Hydroelectric Project             NA
# 4      Project for GHG Emission Reduction by Thermal ...             NA
# ...                                                  ...            ...
# 13168  Reduction in steam consumption through revampi...             NA
# 13169  Usina Petribu Renewable Generation with Sugarc...             NA
# 13170  Power generation from renewable sources  Aiur...             NA
# 13171           Roaring 40s Wind Farms  Private Limited.             NA
# 13172  Energy efficiency measure through dry de-dusti...             NA
#
# [13154 rows x 23 columns]

# %%
df_issuances = pd.read_excel("./input/CDM-Issuances-November.xlsx")
# df_issuances.drop('DOE', axis=1, inplace=True)
df_issuances.drop('PA/PoA', axis=1, inplace=True)
df_issuances.drop('CP', axis=1, inplace=True)
df_issuances.drop('Monitoring report number', axis=1, inplace=True)
df_issuances.drop('Last_updated', axis=1, inplace=True)
df_issuances.drop('Project type (UNEP DTU)', axis=1, inplace=True)
df_issuances.drop('Project subtype (UNEP DTU)', axis=1, inplace=True)
# df_issuances.drop('Units - Total', axis=1, inplace=True)
df_issuances.drop('Issuance date', axis=1, inplace=True)
df_issuances.drop('HostParty', axis=1, inplace=True)


issuances_columns={
    "CDM project reference number":"projectId",
    "DOE":"verificationBody",
    "Issuance process ID":"id",
    "Monitoring report started":"startDate",
    "Monitoring report ended":"endDate",
     "Units - Total":"unitCount",
}
df_issuances['Monitoring report started'] = pd.to_datetime(df_issuances['Monitoring report started'])
df_issuances['Monitoring report ended'] = pd.to_datetime(df_issuances['Monitoring report ended'])
df_issuances['CDM project reference number'] = df_issuances['CDM project reference number'].map(id_to_id)
df_issuances = df_issuances[issuances_columns.keys()].rename(columns=issuances_columns)


df_issuances['verificationReportDate']=df_issuances['projectId'].map(verification_report_date_map)
df_issuances['verificationApproach']="NA"



df_issuances = fillna_by_dtype(df_issuances)
print(len(df_issuances['projectId'].unique()))
df_issuances


# df_aggregated = df_issuances.groupby('projectId')['unitCount'].sum().reset_index()
df_iss_completed = pd.read_excel("./input/CDM_Issuance_Completed_November.xlsx")
df_iss_completed['Project number'] =df_iss_completed['Project number'].map(id_to_id)

df_iss_completed


def rename_duplicates(df, column_name):
   
    df_copy = df.copy()
    duplic = df_copy.duplicated(subset=column_name, keep=False)
    duplicates = df_copy[duplic].copy()
    duplicates['dup_count'] = duplicates.groupby(column_name).cumcount() + 1
    duplicates[column_name] = duplicates[column_name].astype(str) + '-' + duplicates['dup_count'].astype(str)
    duplicates.drop('dup_count', axis=1, inplace=True)
    df_copy.update(duplicates)
    return df_copy

print(len(df_iss_completed))
df_issuances = rename_duplicates(df_issuances, 'id')

df_issuances= df_issuances.merge(
    df_iss_completed, 
    left_on=['projectId', 'unitCount'], 
    right_on=['Project number', 'Total'],
    how='left'
)

df_issuances.drop('Completion date', axis=1, inplace=True)
df_issuances.drop('Transaction type', axis=1, inplace=True)
df_issuances.drop('Total', axis=1, inplace=True)
df_issuances.drop('Project number', axis=1, inplace=True)
df_issuances.drop('PARTY CODE', axis=1, inplace=True)
df_issuances.drop('CP', axis=1, inplace=True)
df_issuances.drop('Unit Type', axis=1, inplace=True)
df_issuances["Status"] = "Held"
df_issuances.drop_duplicates(subset='id', keep='first', inplace=True)
# df_dup_check = df_issuances[df_issuances.duplicated(subset='id', keep=False)]


# df_dup_check
# df_issuances.to_excel("propercleanissuance.xlsx")


nan_exists = df_issuances['SERIAL RANGE'].isna().any()
nan_exists

df_issuances
# Out:
# 3703
# 12570
#                             projectId verificationBody  \
# 0      IBK3RIR7HVE1SZLK7YZMZPZ02UW7TS           KEarth
# 1      KZPP9BVTCRTYEUSRYB2L0ZNRJUDF2X           KEarth
# 2      P2UF559LX39J2VDPTZ13PAZUO3DRVV           KEarth
# 3      AXF2WJ2NOM4CHZGDOJW9S9DINIAQWS           KEarth
# 4      JOUI5BA4DLQS9MVXDKRLL1HHFVQ4M3           KEarth
# ...                               ...              ...
# 12551  3A5UYHPO8SISCX8T4BJ1AMN6SO780J          No info
# 12552  3A5UYHPO8SISCX8T4BJ1AMN6SO780J          No info
# 12553  D4CRFLKI60AFK14YEHRDNPY16829DF          No info
# 12554  BN70H0KER9GB6Y0BPJBJ3Q4IBIXK7C          No info
# 12555  4BDRO6C36JFF9XQ4L3QDAFZ4AX3VW9             LGAI
#
#                            id  startDate    endDate  unitCount  \
# 0        4KEarth1568615888.93 2017-04-01 2019-07-31    20519.0
# 1         4KEarth1568616446.5 2017-04-01 2019-07-31    18925.0
# 2        4KEarth1585297661.77 2018-01-01 2019-12-31    24595.0
# 3        4KEarth1596186178.27 2018-01-01 2020-03-21    43219.0
# 4        4KEarth1599113457.49 2015-04-01 2017-12-31   116637.0
# ...                       ...        ...        ...        ...
# 12551  sergeyf731618828753.52 2016-09-01 2017-09-30  1231148.0
# 12552  sergeyf731618828921.37 2017-10-01 2018-12-08  1128556.0
# 12553   sergeyf731650363867.4 2016-10-01 2017-06-30   434350.0
# 12554    slenzen1552989570.98 2017-01-01 2019-01-31   102514.0
# 12555      sleyh1563531122.32 2018-07-25 2019-04-30    51790.0
#
#       verificationReportDate verificationApproach Status  \
# 0                 2014-01-01                   NA   Held
# 1                 2014-05-31                   NA   Held
# 2                 2011-01-01                   NA   Held
# 3                 2013-03-22                   NA   Held
# 4                 2013-10-10                   NA   Held
# ...                      ...                  ...    ...
# 12551             2013-03-15                   NA   Held
# 12552             2013-03-15                   NA   Held
# 12553             2012-11-01                   NA   Held
# 12554             2013-12-27                   NA   Held
# 12555             2008-10-29                   NA   Held
#
#                   SERIAL RANGE
# 0        258030584 - 258051102
# 1        258051103 - 258070027
# 2        265420302 - 265444896
# 3          14955868 - 14999086
# 4        294645212 - 294761848
# ...                        ...
# 12551    279718404 - 280949551
# 12552    280949552 - 282078107
# 12553  1167744001 - 1168178350
# 12554    256330654 - 256433167
# 12555    153133759 - 153185548
#
# [12548 rows x 10 columns]

# %%
df_units = pd.read_excel("./input/CDM-Issuances-November.xlsx")


units_columns={
    "HostParty":"unitOwner",
    "CDM project reference number":"projectId",
    "Issuance process ID":"issuanceId",
    "DOE":"verificationBody",
    "Issuance process ID":"id",
   "Units - Total":"unitCount",
   "Issuance date":"vintageYear",

}

df_units = df_units[units_columns.keys()].rename(columns=units_columns)
df_units["unitOwner"] = df_units["unitOwner"].map(country_name_map)
df_units["projectId"] = df_units["projectId"].map(id_to_id)
df_units["countryJurisdictionOfOwner"] = df_units["unitOwner"]
df_units["inCountryJurisdictionOfOwner"] = ""
df_units["projectLocationId"] = ""
df_units["geographyIdentifier"] = df_units["unitOwner"].map(geography_map)
df_units["correspondingAdjustmentDeclaration"] = "Unknown"
df_units["unitRegistryLink"] = 'https://cdm.unfccc.int/Projects/Validation/DB/' +df_units['projectId']+"/view.html"
df_units["vintageYear"] = df_units["vintageYear"].astype(str).str[:4]
df_units["unitStatus"] = "Held"
df_units["unitType"] = ""
df_units["unitBlockStart"] = ""
df_units["unitBlockEnd"] = ""


df_units = fillna_by_dtype(df_units)

df_units
# Out:
#       unitOwner                       projectId                      id  \
# 0         India  IBK3RIR7HVE1SZLK7YZMZPZ02UW7TS    4KEarth1568615888.93
# 1         India  KZPP9BVTCRTYEUSRYB2L0ZNRJUDF2X     4KEarth1568616446.5
# 2         India  P2UF559LX39J2VDPTZ13PAZUO3DRVV    4KEarth1585297661.77
# 3      Thailand  AXF2WJ2NOM4CHZGDOJW9S9DINIAQWS    4KEarth1596186178.27
# 4         India  JOUI5BA4DLQS9MVXDKRLL1HHFVQ4M3    4KEarth1599113457.49
# ...         ...                             ...                     ...
# 12543     India  3A5UYHPO8SISCX8T4BJ1AMN6SO780J  sergeyf731618828753.52
# 12544     India  3A5UYHPO8SISCX8T4BJ1AMN6SO780J  sergeyf731618828921.37
# 12545     China  D4CRFLKI60AFK14YEHRDNPY16829DF   sergeyf731650363867.4
# 12546     India  BN70H0KER9GB6Y0BPJBJ3Q4IBIXK7C    slenzen1552989570.98
# 12547    Brazil  4BDRO6C36JFF9XQ4L3QDAFZ4AX3VW9      sleyh1563531122.32
#
#       verificationBody  unitCount vintageYear countryJurisdictionOfOwner  \
# 0               KEarth      20519        2020                      India
# 1               KEarth      18925        2020                      India
# 2               KEarth      24595        2021                      India
# 3               KEarth      43219        2021                   Thailand
# 4               KEarth     116637        2022                      India
# ...                ...        ...         ...                        ...
# 12543          No info    1231148        2022                      India
# 12544          No info    1128556        2022                      India
# 12545          No info     434350        2022                      China
# 12546          No info     102514        2020                      India
# 12547             LGAI      51790        2019                     Brazil
#
#       inCountryJurisdictionOfOwner projectLocationId  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...               ...
# 12543
# 12544
# 12545
# 12546
# 12547
#
#                                  geographyIdentifier  \
# 0        {"latitude":20.593684,"longitude":78.96288}
# 1        {"latitude":20.593684,"longitude":78.96288}
# 2        {"latitude":20.593684,"longitude":78.96288}
# 3      {"latitude":15.870032,"longitude":100.992541}
# 4        {"latitude":20.593684,"longitude":78.96288}
# ...                                              ...
# 12543    {"latitude":20.593684,"longitude":78.96288}
# 12544    {"latitude":20.593684,"longitude":78.96288}
# 12545   {"latitude":35.86166,"longitude":104.195397}
# 12546    {"latitude":20.593684,"longitude":78.96288}
# 12547  {"latitude":-14.235004,"longitude":-51.92528}
#
#       correspondingAdjustmentDeclaration  \
# 0                                Unknown
# 1                                Unknown
# 2                                Unknown
# 3                                Unknown
# 4                                Unknown
# ...                                  ...
# 12543                            Unknown
# 12544                            Unknown
# 12545                            Unknown
# 12546                            Unknown
# 12547                            Unknown
#
#                                         unitRegistryLink unitStatus unitType  \
# 0      https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 1      https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 2      https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 3      https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 4      https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# ...                                                  ...        ...      ...
# 12543  https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 12544  https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 12545  https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 12546  https://cdm.unfccc.int/Projects/Validation/DB/...       Held
# 12547  https://cdm.unfccc.int/Projects/Validation/DB/...       Held
#
#       unitBlockStart unitBlockEnd
# 0
# 1
# 2
# 3
# 4
# ...              ...          ...
# 12543
# 12544
# 12545
# 12546
# 12547
#
# [12548 rows x 16 columns]

# %%
df_retired = pd.read_excel("./input/CDM_Retired_November.xlsx")
df_retired['PARTY CODE'] = df_retired['Project Identifier'].str.split('-').str[0]
df_retired['Project Identifier'] = df_retired['Project Identifier'].str.split('-').str[1].astype(int)



vintage_year_map= df_units.set_index('projectId')['vintageYear'].to_dict()
issuance_id_map= df_units.set_index('projectId')['id'].to_dict()
verif_body_units_map= df_units.set_index('projectId')['verificationBody'].to_dict()
geog_identifier_units_map = df_units.set_index('projectId')['geographyIdentifier'].to_dict()




# df_retired


retired_columns={
    "Status":"unitStatus",
    "Total":"unitTotal",
    "PARTY CODE":"unitOwner",
    "Project Identifier":"projectId",
    "Serial Range":"Serial Range",
    "Transaction Type":"unitStatus"
}



df_retired = df_retired[retired_columns.keys()].rename(columns=retired_columns)
df_retired[['unitBlockStart', 'unitBlockEnd']] = df_retired['Serial Range'].str.split('-', 1, expand=True)
df_retired['unitBlockStart'] = df_retired['unitBlockStart'].fillna(0).astype(int)
df_retired['unitBlockEnd'] = df_retired['unitBlockEnd'].fillna(0).astype(int)
df_retired.drop('Serial Range', axis=1, inplace=True)
df_retired['projectId']=df_retired['projectId'].map(id_to_id)

df_retired["unitOwner"]= df_retired['unitOwner'].map(country_name_map)
df_retired["countryJurisdictionOfOwner"] = df_retired["unitOwner"]
df_retired['inCountryJurisdictionOfOwner'] = ""


df_retired["unitType"] = ""
df_retired["correspondingAdjustmentDeclaration"] = "Unknown"
df_retired["unitRegistryLink"] = 'https://cdm.unfccc.int/Projects/Validation/DB/' +df_retired['projectId']+"/view.html"


df_needed = df_issuances[['projectId', 'id', 'startDate', 'endDate', 
           'unitCount', 'SERIAL RANGE']]
df_needed[['start', 'end']] = df_needed['SERIAL RANGE'].str.split(' - ', expand=True)

# Convert 'start' and 'end' to integers
df_needed['start'] = df_needed['start'].astype(int)
df_needed['end'] = df_needed['end'].astype(int)
df_needed['yearDiff'] = df_needed['endDate'].dt.year - df_needed['startDate'].dt.year
df_needed['countDiff'] = df_needed['end']-df_needed['start']




# Todo df_retired["vintageYear"]= df_retired['projectId'].map(vintage_year_map)
# Todo df_retired["id"]= df_retired['projectId'].map(issuance_id_map)
df_retired["verificationBody"]= df_retired['projectId'].map(verif_body_units_map)
df_retired['geographyIdentifier']= df_retired['projectId'].map(geog_identifier_units_map)
# Todo df_retired["projectLocationId"] = ""
df_retired = fillna_by_dtype(df_retired)
df_retired["unitStatus"] = "Retired"


# df_filtered
# len(df_filtered['id'].unique())

df_needed
# Out:
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/1823546213.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_needed[['start', 'end']] = df_needed['SERIAL RANGE'].str.split(' - ', expand=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/1823546213.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_needed[['start', 'end']] = df_needed['SERIAL RANGE'].str.split(' - ', expand=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/1823546213.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_needed['start'] = df_needed['start'].astype(int)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/1823546213.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_needed['end'] = df_needed['end'].astype(int)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/1823546213.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_needed['yearDiff'] = df_needed['endDate'].dt.year - df_needed['startDate'].dt.year
#                             projectId                      id  startDate  \
# 0      IBK3RIR7HVE1SZLK7YZMZPZ02UW7TS    4KEarth1568615888.93 2017-04-01
# 1      KZPP9BVTCRTYEUSRYB2L0ZNRJUDF2X     4KEarth1568616446.5 2017-04-01
# 2      P2UF559LX39J2VDPTZ13PAZUO3DRVV    4KEarth1585297661.77 2018-01-01
# 3      AXF2WJ2NOM4CHZGDOJW9S9DINIAQWS    4KEarth1596186178.27 2018-01-01
# 4      JOUI5BA4DLQS9MVXDKRLL1HHFVQ4M3    4KEarth1599113457.49 2015-04-01
# ...                               ...                     ...        ...
# 12551  3A5UYHPO8SISCX8T4BJ1AMN6SO780J  sergeyf731618828753.52 2016-09-01
# 12552  3A5UYHPO8SISCX8T4BJ1AMN6SO780J  sergeyf731618828921.37 2017-10-01
# 12553  D4CRFLKI60AFK14YEHRDNPY16829DF   sergeyf731650363867.4 2016-10-01
# 12554  BN70H0KER9GB6Y0BPJBJ3Q4IBIXK7C    slenzen1552989570.98 2017-01-01
# 12555  4BDRO6C36JFF9XQ4L3QDAFZ4AX3VW9      sleyh1563531122.32 2018-07-25
#
#          endDate  unitCount             SERIAL RANGE       start         end  \
# 0     2019-07-31    20519.0    258030584 - 258051102   258030584   258051102
# 1     2019-07-31    18925.0    258051103 - 258070027   258051103   258070027
# 2     2019-12-31    24595.0    265420302 - 265444896   265420302   265444896
# 3     2020-03-21    43219.0      14955868 - 14999086    14955868    14999086
# 4     2017-12-31   116637.0    294645212 - 294761848   294645212   294761848
# ...          ...        ...                      ...         ...         ...
# 12551 2017-09-30  1231148.0    279718404 - 280949551   279718404   280949551
# 12552 2018-12-08  1128556.0    280949552 - 282078107   280949552   282078107
# 12553 2017-06-30   434350.0  1167744001 - 1168178350  1167744001  1168178350
# 12554 2019-01-31   102514.0    256330654 - 256433167   256330654   256433167
# 12555 2019-04-30    51790.0    153133759 - 153185548   153133759   153185548
#
#        yearDiff  countDiff
# 0             2      20518
# 1             2      18924
# 2             1      24594
# 3             2      43218
# 4             2     116636
# ...         ...        ...
# 12551         1    1231147
# 12552         1    1128555
# 12553         1     434349
# 12554         2     102513
# 12555         1      51789
#
# [12548 rows x 10 columns]

# %%
df_retired
# Out:
#       unitStatus  unitTotal unitOwner                       projectId  \
# 0        Retired       5294    Brazil  DWXTGTQLAORUROS9KPVZJUSGI8UK70
# 1        Retired       5294    Brazil  8J911GX7NLREEIL5L09MKJTI9USERE
# 2        Retired       5000    Brazil  O5C8ZV4YZTL3001AX5RD5V1OL5OM0A
# 3        Retired       5000    Brazil  HY2WB5CJ5DZTLBFLQE55ZHT0XK2DO2
# 4        Retired       5000    Brazil  0IET49KTMORLOP6NX7Q56DF7HXTMPV
# ...          ...        ...       ...                             ...
# 27741    Retired          3     Chile  L9H0347KVT9F7MAMD49TAYUJLMFHEW
# 27742    Retired          1     China  B90WLUX8QKF2591LN21LEVJ82HOO75
# 27743    Retired        186    Malawi  YHNSTOHUC3NLV2APHHB6SCWA61Q46T
# 27744    Retired        129     India  82ORS4DFFAE3F7JI64VMOSYQEYXGCB
# 27745    Retired       1677    Malawi  G8WF6TLTG80XJCQJCZOIX6XI7WDNZ9
#
#       unitStatus  unitBlockStart  unitBlockEnd countryJurisdictionOfOwner  \
# 0        Retired        65142364      65147657                     Brazil
# 1        Retired        60482913      60488206                     Brazil
# 2        Retired        57297956      57302955                     Brazil
# 3        Retired        61682096      61687095                     Brazil
# 4        Retired        57923146      57928145                     Brazil
# ...          ...             ...           ...                        ...
# 27741    Retired        41951955      41951957                      Chile
# 27742    Retired      1185996159    1185996159                      China
# 27743    Retired          207935        208120                     Malawi
# 27744    Retired       279636945     279637073                      India
# 27745    Retired          362561        364237                     Malawi
#
#       inCountryJurisdictionOfOwner unitType  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...      ...
# 27741
# 27742
# 27743
# 27744
# 27745
#
#       correspondingAdjustmentDeclaration  \
# 0                                Unknown
# 1                                Unknown
# 2                                Unknown
# 3                                Unknown
# 4                                Unknown
# ...                                  ...
# 27741                            Unknown
# 27742                            Unknown
# 27743                            Unknown
# 27744                            Unknown
# 27745                            Unknown
#
#                                         unitRegistryLink verificationBody  \
# 0      https://cdm.unfccc.int/Projects/Validation/DB/...             RINA
# 1      https://cdm.unfccc.int/Projects/Validation/DB/...         TUV NORD
# 2      https://cdm.unfccc.int/Projects/Validation/DB/...              DNV
# 3      https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
# 4      https://cdm.unfccc.int/Projects/Validation/DB/...              DNV
# ...                                                  ...              ...
# 27741  https://cdm.unfccc.int/Projects/Validation/DB/...         TUV NORD
# 27742  https://cdm.unfccc.int/Projects/Validation/DB/...             LGAI
# 27743  https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
# 27744  https://cdm.unfccc.int/Projects/Validation/DB/...             LGAI
# 27745  https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
#
#                                   geographyIdentifier
# 0       {"latitude":-14.235004,"longitude":-51.92528}
# 1       {"latitude":-14.235004,"longitude":-51.92528}
# 2       {"latitude":-14.235004,"longitude":-51.92528}
# 3       {"latitude":-14.235004,"longitude":-51.92528}
# 4       {"latitude":-14.235004,"longitude":-51.92528}
# ...                                               ...
# 27741  {"latitude":-35.675147,"longitude":-71.542969}
# 27742    {"latitude":35.86166,"longitude":104.195397}
# 27743   {"latitude":-13.254308,"longitude":34.301525}
# 27744     {"latitude":20.593684,"longitude":78.96288}
# 27745   {"latitude":-13.254308,"longitude":34.301525}
#
# [27746 rows x 14 columns]

# %%
df_merged = pd.merge(df_retired, df_needed, on='projectId', how='left', suffixes=('_retired', '_issuance'))

# Filter rows where unitBlockStart and unitBlockEnd are within the start and end range
df_linked = df_merged[(df_merged['unitBlockStart'] >= df_merged['start']) & (df_merged['unitBlockEnd'] <= df_merged['end'])]





def checker_playaround(projectId):

    filtered_braz = df_linked[df_linked['projectId'] == projectId]


    fil_ori = df_retired[df_retired['projectId']== projectId]

    fil_haha = df_needed[df_needed['projectId']== projectId]
    # filtered_braz.to_excel("testlook.xlsx")
    print("unique issuance id here is",filtered_braz['id'].unique())
    print("unique issuance id here is",fil_haha['id'].unique())
    print("total length 1",len(fil_ori))
    print("total length 2",len(filtered_braz))




df_linked

df_linked['startDate'] = pd.to_datetime(df_linked['startDate'])
df_linked['endDate'] = pd.to_datetime(df_linked['endDate'])

# Function to calculate vintage year
def calculate_vintage_year(row):
    total_years = row['endDate'].year - row['startDate'].year
    total_years = max(total_years, 1)  # Ensure total_years is at least 1
    units_per_year = row['unitCount'] / total_years
    year_offset = (row['unitBlockStart'] - row['start']) // units_per_year
    return row['startDate'].year + int(year_offset)

# Apply the function to each row
df_linked['vintageYear'] = df_linked.apply(calculate_vintage_year, axis=1)




checker_playaround("B90WLUX8QKF2591LN21LEVJ82HOO75")

df_linked_2016 = df_linked[df_linked['startDate'].dt.year >= 2016]


df_linked.columns

# total 3392 retired units
df_linked_2016

print("Issuances belong to retired units 2016",len(df_linked_2016['id'].unique()))


# after 2016 

# df_linked = df_linked[df_linked['startDate'].dt.year >= 2016]

# before 2016
df_linked = df_linked[df_linked['startDate'].dt.year < 2016]
print("Issuances belong to retired units before 2016",len(df_linked['id'].unique()))

df_linked
# Out:
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/2259019014.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_linked['startDate'] = pd.to_datetime(df_linked['startDate'])
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/2259019014.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_linked['endDate'] = pd.to_datetime(df_linked['endDate'])
# unique issuance id here is ['Applus1654080342.92-2' 'Applus1654080342.92-1']
# unique issuance id here is ['Applus1654080342.92-1' 'Applus1654080342.92-2']
# total length 1 66
# total length 2 66
# Issuances belong to retired units 2016 450
# Issuances belong to retired units before 2016 1279
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/2259019014.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_linked['vintageYear'] = df_linked.apply(calculate_vintage_year, axis=1)
#        unitStatus  unitTotal unitOwner                       projectId  \
# 0         Retired       5294    Brazil  DWXTGTQLAORUROS9KPVZJUSGI8UK70
# 6         Retired       5294    Brazil  8J911GX7NLREEIL5L09MKJTI9USERE
# 18        Retired       5000    Brazil  O5C8ZV4YZTL3001AX5RD5V1OL5OM0A
# 36        Retired       5000    Brazil  HY2WB5CJ5DZTLBFLQE55ZHT0XK2DO2
# 43        Retired       5000    Brazil  0IET49KTMORLOP6NX7Q56DF7HXTMPV
# ...           ...        ...       ...                             ...
# 130472    Retired          3     Chile  L9H0347KVT9F7MAMD49TAYUJLMFHEW
# 130476    Retired          1     China  B90WLUX8QKF2591LN21LEVJ82HOO75
# 130478    Retired        186    Malawi  YHNSTOHUC3NLV2APHHB6SCWA61Q46T
# 130479    Retired        129     India  82ORS4DFFAE3F7JI64VMOSYQEYXGCB
# 130482    Retired       1677    Malawi  G8WF6TLTG80XJCQJCZOIX6XI7WDNZ9
#
#        unitStatus  unitBlockStart  unitBlockEnd countryJurisdictionOfOwner  \
# 0         Retired        65142364      65147657                     Brazil
# 6         Retired        60482913      60488206                     Brazil
# 18        Retired        57297956      57302955                     Brazil
# 36        Retired        61682096      61687095                     Brazil
# 43        Retired        57923146      57928145                     Brazil
# ...           ...             ...           ...                        ...
# 130472    Retired        41951955      41951957                      Chile
# 130476    Retired      1185996159    1185996159                      China
# 130478    Retired          207935        208120                     Malawi
# 130479    Retired       279636945     279637073                      India
# 130482    Retired          362561        364237                     Malawi
#
#        inCountryJurisdictionOfOwner unitType  ...                      id  \
# 0                                             ...    DNV-CUK1293110659.42
# 6                                             ...     DNV-CUK1299845791.9
# 18                                            ...    DNV-CUK1264416604.37
# 36                                            ...  TUEV-SUED1317711892.85
# 43                                            ...    DNV-CUK1265191517.98
# ...                             ...      ...  ...                     ...
# 130472                                        ...     Applus1654182155.66
# 130476                                        ...   Applus1654080342.92-2
# 130478                                        ...  TUEV-SUED1446721135.84
# 130479                                        ...   Applus1557750802.84-1
# 130482                                        ...       ESPL1478153711.44
#
#         startDate    endDate  unitCount             SERIAL RANGE  \
# 0      2000-11-10 2010-11-09  4072355.0      63069791 - 67142145
# 6      2010-07-01 2011-02-28   157369.0      60445682 - 60603050
# 18     2006-10-01 2009-09-30    89641.0      57287379 - 57377019
# 36     2011-06-01 2011-09-30    93646.0      61680223 - 61773868
# 43     2008-06-01 2009-05-31   157914.0      57831988 - 57989901
# ...           ...        ...        ...                      ...
# 130472 2013-07-30 2019-03-17  1541464.0      41762547 - 43304010
# 130476 2013-01-01 2017-12-04   707684.0  1185849127 - 1186556810
# 130478 2014-10-27 2015-08-05    35318.0          172850 - 208167
# 130479 2013-01-01 2016-10-01    71478.0    279587171 - 279658648
# 130482 2015-07-22 2016-08-11    54266.0          326496 - 380761
#
#                start           end  yearDiff  countDiff  vintageYear
# 0       6.306979e+07  6.714214e+07      10.0  4072354.0         2005
# 6       6.044568e+07  6.060305e+07       1.0   157368.0         2010
# 18      5.728738e+07  5.737702e+07       3.0    89640.0         2006
# 36      6.168022e+07  6.177387e+07       0.0    93645.0         2011
# 43      5.783199e+07  5.798990e+07       1.0   157913.0         2008
# ...              ...           ...       ...        ...          ...
# 130472  4.176255e+07  4.330401e+07       6.0  1541463.0         2013
# 130476  1.185849e+09  1.186557e+09       4.0   707683.0         2013
# 130478  1.728500e+05  2.081670e+05       1.0    35317.0         2014
# 130479  2.795872e+08  2.796586e+08       3.0    71477.0         2015
# 130482  3.264960e+05  3.807610e+05       1.0    54265.0         2015
#
# [24357 rows x 24 columns]

# %%
df_retired_clean = df_linked.copy()


print(df_retired_clean.columns)



columns_df_linked = ['unitStatus', 'unitTotal', 'unitOwner', 'projectId', 'unitStatus',
                     'unitBlockStart', 'unitBlockEnd', 'countryJurisdictionOfOwner',
                     'inCountryJurisdictionOfOwner', 'unitType',
                     'correspondingAdjustmentDeclaration', 'unitRegistryLink',
                     'verificationBody', 'geographyIdentifier', 'id', 'startDate', 'endDate',
                     'unitCount', 'SERIAL RANGE', 'start', 'end', 'yearDiff', 'countDiff',
                     'vintageYear']

# List of columns in df_retired_need
columns_df_retired_need = ['unitStatus', 'unitTotal', 'unitOwner', 'projectId', 'unitStatus',
                           'unitBlockStart', 'unitBlockEnd', 'countryJurisdictionOfOwner',
                           'inCountryJurisdictionOfOwner', 'unitType',
                           'correspondingAdjustmentDeclaration', 'unitRegistryLink',
                           'verificationBody', 'geographyIdentifier', 'vintageYear']

# Columns in df_retired_need but not in df_linked
columns_not_in_linked = set(columns_df_retired_need) - set(columns_df_linked)

# Print the result
print("not in the linke dis", columns_not_in_linked)

# WILL NEED ID LATER
df_retired_clean = df_retired_clean[['unitStatus', 'unitTotal', 'unitOwner', 'projectId', 'unitStatus',
       'unitBlockStart', 'unitBlockEnd', 'countryJurisdictionOfOwner',
       'inCountryJurisdictionOfOwner', 'unitType',
       'correspondingAdjustmentDeclaration', 'unitRegistryLink',
       'verificationBody', 'geographyIdentifier','vintageYear','id']]

df_retired_clean.rename(columns={'unitTotal': 'unitCount'}, inplace=True)

df_retired_clean = df_retired_clean.loc[:,~df_retired_clean.columns.duplicated()]

print(len(df_retired_clean.columns))
df_retired_clean.columns


bhutan_projects = df_project[df_project['country'] == 'Bhutan']
bhutan_project_ids = bhutan_projects['projectId'].tolist()
# Filter df_issuance to remove rows where 'projectId' matches those in bhutan_project_ids
df_retired_clean= df_retired_clean[~df_retired_clean['projectId'].isin(bhutan_project_ids)]


df_retired_clean
# Out:
# Index(['unitStatus', 'unitTotal', 'unitOwner', 'projectId', 'unitStatus',
#        'unitBlockStart', 'unitBlockEnd', 'countryJurisdictionOfOwner',
#        'inCountryJurisdictionOfOwner', 'unitType',
#        'correspondingAdjustmentDeclaration', 'unitRegistryLink',
#        'verificationBody', 'geographyIdentifier', 'id', 'startDate', 'endDate',
#        'unitCount', 'SERIAL RANGE', 'start', 'end', 'yearDiff', 'countDiff',
#        'vintageYear'],
#       dtype='object')
# not in the linke dis set()
# 15
#        unitStatus  unitCount unitOwner                       projectId  \
# 0         Retired       5294    Brazil  DWXTGTQLAORUROS9KPVZJUSGI8UK70
# 6         Retired       5294    Brazil  8J911GX7NLREEIL5L09MKJTI9USERE
# 18        Retired       5000    Brazil  O5C8ZV4YZTL3001AX5RD5V1OL5OM0A
# 36        Retired       5000    Brazil  HY2WB5CJ5DZTLBFLQE55ZHT0XK2DO2
# 43        Retired       5000    Brazil  0IET49KTMORLOP6NX7Q56DF7HXTMPV
# ...           ...        ...       ...                             ...
# 130472    Retired          3     Chile  L9H0347KVT9F7MAMD49TAYUJLMFHEW
# 130476    Retired          1     China  B90WLUX8QKF2591LN21LEVJ82HOO75
# 130478    Retired        186    Malawi  YHNSTOHUC3NLV2APHHB6SCWA61Q46T
# 130479    Retired        129     India  82ORS4DFFAE3F7JI64VMOSYQEYXGCB
# 130482    Retired       1677    Malawi  G8WF6TLTG80XJCQJCZOIX6XI7WDNZ9
#
#         unitBlockStart  unitBlockEnd countryJurisdictionOfOwner  \
# 0             65142364      65147657                     Brazil
# 6             60482913      60488206                     Brazil
# 18            57297956      57302955                     Brazil
# 36            61682096      61687095                     Brazil
# 43            57923146      57928145                     Brazil
# ...                ...           ...                        ...
# 130472        41951955      41951957                      Chile
# 130476      1185996159    1185996159                      China
# 130478          207935        208120                     Malawi
# 130479       279636945     279637073                      India
# 130482          362561        364237                     Malawi
#
#        inCountryJurisdictionOfOwner unitType  \
# 0
# 6
# 18
# 36
# 43
# ...                             ...      ...
# 130472
# 130476
# 130478
# 130479
# 130482
#
#        correspondingAdjustmentDeclaration  \
# 0                                 Unknown
# 6                                 Unknown
# 18                                Unknown
# 36                                Unknown
# 43                                Unknown
# ...                                   ...
# 130472                            Unknown
# 130476                            Unknown
# 130478                            Unknown
# 130479                            Unknown
# 130482                            Unknown
#
#                                          unitRegistryLink verificationBody  \
# 0       https://cdm.unfccc.int/Projects/Validation/DB/...             RINA
# 6       https://cdm.unfccc.int/Projects/Validation/DB/...         TUV NORD
# 18      https://cdm.unfccc.int/Projects/Validation/DB/...              DNV
# 36      https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
# 43      https://cdm.unfccc.int/Projects/Validation/DB/...              DNV
# ...                                                   ...              ...
# 130472  https://cdm.unfccc.int/Projects/Validation/DB/...         TUV NORD
# 130476  https://cdm.unfccc.int/Projects/Validation/DB/...             LGAI
# 130478  https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
# 130479  https://cdm.unfccc.int/Projects/Validation/DB/...             LGAI
# 130482  https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
#
#                                    geographyIdentifier  vintageYear  \
# 0        {"latitude":-14.235004,"longitude":-51.92528}         2005
# 6        {"latitude":-14.235004,"longitude":-51.92528}         2010
# 18       {"latitude":-14.235004,"longitude":-51.92528}         2006
# 36       {"latitude":-14.235004,"longitude":-51.92528}         2011
# 43       {"latitude":-14.235004,"longitude":-51.92528}         2008
# ...                                                ...          ...
# 130472  {"latitude":-35.675147,"longitude":-71.542969}         2013
# 130476    {"latitude":35.86166,"longitude":104.195397}         2013
# 130478   {"latitude":-13.254308,"longitude":34.301525}         2014
# 130479     {"latitude":20.593684,"longitude":78.96288}         2015
# 130482   {"latitude":-13.254308,"longitude":34.301525}         2015
#
#                             id
# 0         DNV-CUK1293110659.42
# 6          DNV-CUK1299845791.9
# 18        DNV-CUK1264416604.37
# 36      TUEV-SUED1317711892.85
# 43        DNV-CUK1265191517.98
# ...                        ...
# 130472     Applus1654182155.66
# 130476   Applus1654080342.92-2
# 130478  TUEV-SUED1446721135.84
# 130479   Applus1557750802.84-1
# 130482       ESPL1478153711.44
#
# [24357 rows x 15 columns]

# %%
df_units_linked= df_linked.copy()

print("lenoriginal dfUnitsHeld",len(df_units_linked))

grouped_total = df_units_linked.groupby('id')['unitTotal'].sum().reset_index()
grouped_total.rename(columns={'unitTotal': 'aggregatedUnitTotal'}, inplace=True)

# Step 2: Merge the aggregated data back into df_linked
df_units_held = df_units_linked.merge(grouped_total, on='id', how='left')

# Step 3: Calculate totalHeld
df_units_held['totalHeld'] = df_units_held['unitCount'] - df_units_held['aggregatedUnitTotal']

totalHeld_mapping = df_units_held.set_index('id')['totalHeld'].to_dict()




df_units_held

print("len df units held",len(df_units_held))
totalHeld_mapping
duplicate_rows = df_units_held[df_units_held['id'].duplicated()]

# df_units_held = df_issuances[df_issuances['startDate'].dt.year >= 2016]
df_units_held = df_issuances[df_issuances['startDate'].dt.year < 2016]


print("len df units held",len(df_units_held))

df_units_held['totalHeld'] = df_issuances['id'].map(totalHeld_mapping)
df_units_held['totalHeld'] = df_units_held['totalHeld'].fillna(df_units_held['unitCount'])
# df_see = df_units_held[['id','totalHeld','unitCount']]

df_units_held.drop('unitCount',axis=1,inplace=True)

print("df_units_held column is",df_units_held.columns)



df_units_held.rename(columns={'totalHeld': 'unitCount'}, inplace=True)


# df_units_held.to_excel("df_heldinspect.xlsx")
print(df_units_held.columns)

df_units_held[['unitBlockStart', 'unitBlockEnd']] = df_units_held['SERIAL RANGE'].str.split('-', 1, expand=True)
df_units_held.drop('SERIAL RANGE', axis=1, inplace=True)

df_units_held['unitOwner'] = df_units_held['projectId'].map(projID_to_country)

df_units_held["countryJurisdictionOfOwner"] = df_units_held["unitOwner"]
df_units_held["inCountryJurisdictionOfOwner"] = ""
df_units_held["projectLocationId"] = ""


df_units_held.rename(columns={'Project number': 'projectId'}, inplace=True)
df_units_held["geographyIdentifier"] = df_units_held["unitOwner"].map(geography_map)
df_units_held.rename(columns={'Status': 'unitStatus'}, inplace=True)
df_units_held['unitRegistryLink'] = 'https://cdm.unfccc.int/Projects/Validation/DB/' +df_units_held['projectId']+"/view.html"
df_units_held['correspondingAdjustmentDeclaration'] = "Unknown"
df_units_held['unitType'] =""
df_units_held['vintageYear'] =df_units_held['startDate'].dt.year



columns_to_drop = ['verificationReportDate', 'startDate', 'projectLocationId', 
                   'endDate', 'verificationApproach']

# Dropping the columns
df_units_held = df_units_held.drop(columns=columns_to_drop)

df_units_held.columns


print(set(df_units_held.columns)-set(df_retired_clean.columns))
print(set(df_retired_clean.columns)-set(df_units_held.columns))


print(df_retired_clean.columns)

print(df_units_held.columns)
print(len(df_units_held.columns)-len(df_retired_clean.columns))


df_units_held

# print(df_see['totalHeld'].unique())

df_units_held['vintageYear'].unique()
df_units_held['unitBlockEnd'] = pd.to_numeric(df_units_held['unitBlockEnd'], errors='coerce')
df_units_held['unitCount'] = pd.to_numeric(df_units_held['unitCount'], errors='coerce')

# Update 'unitBlockStart' based on the calculation
df_units_held['unitBlockStart'] = df_units_held['unitBlockEnd'] - df_units_held['unitCount']
bhutan_projects = df_project[df_project['country'] == 'Bhutan']
bhutan_project_ids = bhutan_projects['projectId'].tolist()
# Filter df_issuance to remove rows where 'projectId' matches those in bhutan_project_ids
df_units_held= df_units_held[~df_units_held['projectId'].isin(bhutan_project_ids)]




df_units_held
# df_units_held
# Out:
# lenoriginal dfUnitsHeld 24357
# len df units held 24357
# len df units held 10997
# df_units_held column is Index(['projectId', 'verificationBody', 'id', 'startDate', 'endDate',
#        'verificationReportDate', 'verificationApproach', 'Status',
#        'SERIAL RANGE', 'totalHeld'],
#       dtype='object')
# Index(['projectId', 'verificationBody', 'id', 'startDate', 'endDate',
#        'verificationReportDate', 'verificationApproach', 'Status',
#        'SERIAL RANGE', 'unitCount'],
#       dtype='object')
# set()
# set()
# Index(['unitStatus', 'unitCount', 'unitOwner', 'projectId', 'unitBlockStart',
#        'unitBlockEnd', 'countryJurisdictionOfOwner',
#        'inCountryJurisdictionOfOwner', 'unitType',
#        'correspondingAdjustmentDeclaration', 'unitRegistryLink',
#        'verificationBody', 'geographyIdentifier', 'vintageYear', 'id'],
#       dtype='object')
# Index(['projectId', 'verificationBody', 'id', 'unitStatus', 'unitCount',
#        'unitBlockStart', 'unitBlockEnd', 'unitOwner',
#        'countryJurisdictionOfOwner', 'inCountryJurisdictionOfOwner',
#        'geographyIdentifier', 'unitRegistryLink',
#        'correspondingAdjustmentDeclaration', 'unitType', 'vintageYear'],
#       dtype='object')
# 0
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['totalHeld'] = df_issuances['id'].map(totalHeld_mapping)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['totalHeld'] = df_units_held['totalHeld'].fillna(df_units_held['unitCount'])
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held.drop('unitCount',axis=1,inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held.rename(columns={'totalHeld': 'unitCount'}, inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held[['unitBlockStart', 'unitBlockEnd']] = df_units_held['SERIAL RANGE'].str.split('-', 1, expand=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held[['unitBlockStart', 'unitBlockEnd']] = df_units_held['SERIAL RANGE'].str.split('-', 1, expand=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held.drop('SERIAL RANGE', axis=1, inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['unitOwner'] = df_units_held['projectId'].map(projID_to_country)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held["countryJurisdictionOfOwner"] = df_units_held["unitOwner"]
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held["inCountryJurisdictionOfOwner"] = ""
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held["projectLocationId"] = ""
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held.rename(columns={'Project number': 'projectId'}, inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held["geographyIdentifier"] = df_units_held["unitOwner"].map(geography_map)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held.rename(columns={'Status': 'unitStatus'}, inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['unitRegistryLink'] = 'https://cdm.unfccc.int/Projects/Validation/DB/' +df_units_held['projectId']+"/view.html"
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['correspondingAdjustmentDeclaration'] = "Unknown"
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['unitType'] =""
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_27168/689403579.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_units_held['vintageYear'] =df_units_held['startDate'].dt.year
#                             projectId verificationBody  \
# 4      JOUI5BA4DLQS9MVXDKRLL1HHFVQ4M3           KEarth
# 19     3S36PU919D94NR86U2XFCMDKMOAQ7A           KEarth
# 20     RSHGKPZYMN0MDMI7OP4LEA4ULNIVY1           KEarth
# 21     RSHGKPZYMN0MDMI7OP4LEA4ULNIVY1           KEarth
# 26     0LXRXT5CK6WUWY5Q9RSNQI6RSXFGS8           KEarth
# ...                               ...              ...
# 12545  NIPF5RRFPIJB9Q89LNDCRQWB51GBXQ         Earthood
# 12546  L5NM3ZT1NP8125Z00TJ5E6XNLZ3MIV     Carbon Check
# 12547  AYYW2EJ3HYUNKG1IW90202KP44Z2NM              KBS
# 12549  IO57673HO8JNI4YN42UGAYDXU76BXA          No info
# 12550  3A5UYHPO8SISCX8T4BJ1AMN6SO780J          No info
#
#                            id unitStatus  unitCount  unitBlockStart  \
# 4        4KEarth1599113457.49       Held   116637.0     294645211.0
# 19       4KEarth1640788887.99       Held   539881.0     316763401.0
# 20     4KEarth1641211288.18-1       Held   241873.0     324764016.0
# 21     4KEarth1641211288.18-2       Held      867.0     325005889.0
# 26     4KEarth1648863914.34-1       Held    66817.0     321126168.0
# ...                       ...        ...        ...             ...
# 12545      poaiss997180415~NG       Held        7.0       3426126.0
# 12546         poaiss998042239       Held    27286.0        168055.0
# 12547      poaiss999064138~TH       Held    40659.0      12580003.0
# 12549  sergeyf731608560024.14       Held     2485.0      15253612.0
# 12550  sergeyf731618827547.72       Held    28880.0     279244827.0
#
#        unitBlockEnd unitOwner countryJurisdictionOfOwner  \
# 4         294761848     India                      India
# 19        317303282     India                      India
# 20        325005889     India                      India
# 21        325006756     India                      India
# 26        321192985     India                      India
# ...             ...       ...                        ...
# 12545       3426133     Ghana                      Ghana
# 12546        195341     Ghana                      Ghana
# 12547      12620662  Thailand                   Thailand
# 12549      15256097  Thailand                   Thailand
# 12550     279273707     India                      India
#
#       inCountryJurisdictionOfOwner  \
# 4
# 19
# 20
# 21
# 26
# ...                            ...
# 12545
# 12546
# 12547
# 12549
# 12550
#
#                                  geographyIdentifier  \
# 4        {"latitude":20.593684,"longitude":78.96288}
# 19       {"latitude":20.593684,"longitude":78.96288}
# 20       {"latitude":20.593684,"longitude":78.96288}
# 21       {"latitude":20.593684,"longitude":78.96288}
# 26       {"latitude":20.593684,"longitude":78.96288}
# ...                                              ...
# 12545    {"latitude":7.946527,"longitude":-1.023194}
# 12546    {"latitude":7.946527,"longitude":-1.023194}
# 12547  {"latitude":15.870032,"longitude":100.992541}
# 12549  {"latitude":15.870032,"longitude":100.992541}
# 12550    {"latitude":20.593684,"longitude":78.96288}
#
#                                         unitRegistryLink  \
# 4      https://cdm.unfccc.int/Projects/Validation/DB/...
# 19     https://cdm.unfccc.int/Projects/Validation/DB/...
# 20     https://cdm.unfccc.int/Projects/Validation/DB/...
# 21     https://cdm.unfccc.int/Projects/Validation/DB/...
# 26     https://cdm.unfccc.int/Projects/Validation/DB/...
# ...                                                  ...
# 12545  https://cdm.unfccc.int/Projects/Validation/DB/...
# 12546  https://cdm.unfccc.int/Projects/Validation/DB/...
# 12547  https://cdm.unfccc.int/Projects/Validation/DB/...
# 12549  https://cdm.unfccc.int/Projects/Validation/DB/...
# 12550  https://cdm.unfccc.int/Projects/Validation/DB/...
#
#       correspondingAdjustmentDeclaration unitType  vintageYear
# 4                                Unknown                  2015
# 19                               Unknown                  2013
# 20                               Unknown                  2013
# 21                               Unknown                  2012
# 26                               Unknown                  2013
# ...                                  ...      ...          ...
# 12545                            Unknown                  2013
# 12546                            Unknown                  2014
# 12547                            Unknown                  2015
# 12549                            Unknown                  2013
# 12550                            Unknown                  2013
#
# [10995 rows x 15 columns]

# %%
# CHecking qc
df_units_held.to_excel("./output/CDM_Held_Units_Cleaned.xlsx")
df_retired_clean.to_excel("./output/CDM_Retired_Units_Cleaned.xlsx")
# df_issuances.to_excel("./output/CDM_Issuances_Cleaned.xlsx")

df_issuances_cleaned = df_issuances[["verificationBody","projectId","id","startDate","endDate","verificationReportDate","verificationApproach"]]
# df_issuances_cleaned =df_issuances_cleaned[df_issuances_cleaned['startDate'].dt.year >= 2016]


df_issuances_cleaned =df_issuances_cleaned[df_issuances_cleaned['startDate'].dt.year < 2016]



bhutan_projects = df_project[df_project['country'] == 'Bhutan']
bhutan_project_ids = bhutan_projects['projectId'].tolist()
# Filter df_issuance to remove rows where 'projectId' matches those in bhutan_project_ids
df_issuances_cleaned= df_issuances_cleaned[~df_issuances_cleaned['projectId'].isin(bhutan_project_ids)]


unique_ids_held = df_units_held['id'].unique()
unique_ids_retired = df_retired_clean['id'].unique()
unique_ids_issuances = df_issuances_cleaned['id'].unique()


# df_filtered = df_needed[df_needed['startDate'].dt.year >= 2016]



print(set((unique_ids_retired))-set((unique_ids_held)))
print(set((unique_ids_retired))-set((unique_ids_issuances)))
print(set((unique_ids_issuances))-set((unique_ids_held)))
print(set((unique_ids_held))-set((unique_ids_issuances)))

def convert_timestamp_to_string(x):
    if isinstance(x, pd.Timestamp):
        return x.strftime('%Y-%m-%d %H:%M:%S')
    return x

# Columns that contain Timestamps
timestamp_columns = ['startDate', 'endDate', 'verificationReportDate']

# Apply the conversion to the specific columns

# Apply the conversion to the existing timestamp columns
df_issuances_cleaned[timestamp_columns] = df_issuances_cleaned[timestamp_columns].applymap(convert_timestamp_to_string)
issuances_grouped = df_issuances_cleaned.groupby('projectId').apply(lambda x: x.to_dict(orient='records')).reset_index(name='issuances')

issuances_grouped['issuances'][0]


df_issuances_cleaned

# df_issuances_cleaned

issuances_grouped.to_excel("./output/grouped_issuances_bef_2016.xlsx")

df_issuances_cleaned
issuances_grouped
# Out:
# set()
# set()
# set()
# set()
#                            projectId  \
# 0     00J4UE52C4VTT01JSVE9ERDU8WP76W
# 1     00MPVBXC6YBLA33C1NN1G3K33VHK1V
# 2     015ESW8TY1JO2B2E0T0EP4ZZQKQM5D
# 3     01BHKDBIJYIMU1ZSLWRZX238VM5FJU
# 4     01GN1N0RHE2KY6CRDPWDNY7ELCZKNT
# ...                              ...
# 3559  ZYXH65I6FVRCHO68AS8K64WYFS3V2O
# 3560  ZZ2UA0ANWJAF7LL3BE60P5HG1LRLAJ
# 3561  ZZ99SW9AQ4MM9WTA4H7WGK2IQZ9BZK
# 3562  ZZK6XB1XUWV596IZZ4H06G6E9KBC1G
# 3563  ZZKS904BYTBWYDDITR4TN1CEWCUDAX
#
#                                               issuances
# 0     [{'verificationBody': 'RINA', 'projectId': '00...
# 1     [{'verificationBody': 'TUV NORD', 'projectId':...
# 2     [{'verificationBody': 'TSUS', 'projectId': '01...
# 3     [{'verificationBody': 'BVCH', 'projectId': '01...
# 4     [{'verificationBody': 'LGAI', 'projectId': '01...
# ...                                                 ...
# 3559  [{'verificationBody': 'BVCH', 'projectId': 'ZY...
# 3560  [{'verificationBody': 'LGAI', 'projectId': 'ZZ...
# 3561  [{'verificationBody': 'KTR', 'projectId': 'ZZ9...
# 3562  [{'verificationBody': 'LGAI', 'projectId': 'ZZ...
# 3563  [{'verificationBody': 'ICONTEC', 'projectId': ...
#
# [3564 rows x 2 columns]

# %%
url_project_local = "http://localhost:31310/v1/projects"


def datetime_to_string(value):
    if isinstance(value, datetime):
        return value.strftime("%Y-%m-%d")
    return value
# Function to send POST request for each row in the DataFrame
def post_projects(df,start_idx,end_idx,url,type,id_mapping,issuance_mapping):
    # Iterate over each row in the DataFrame
    project_to_uuid_mapping = {}
    i=0
    for index, row in df[start_idx:end_idx].iterrows():
    
        request_body = row.to_dict()
        request_body = {k: datetime_to_string(v) for k, v in row.to_dict().items()}
        request_body['projectLocations'] = [
            {
                "country": request_body.get('country', 'Unknown'),
                "inCountryRegion": request_body.get('inCountryRegion', 'Unknown'),
                "geographicIdentifier":request_body.get('geographicIdentifier',{})  # replace with actual geographicIdentifier if available
            }
        ]

        issuance_ids = []
        issuances_for_api = []

        # Uncomment Later 
        if row.get('issuances') is not None and isinstance(row.get('issuances'), list):
            for issuance in row.get('issuances', []):
                # Store the 'id' for later use
                issuance_id = issuance.get('id')
                issuance_ids.append(issuance_id)
                
                # Remove 'id' from the issuance data sent to the API
                issuance_for_api = {key: value for key, value in issuance.items() if key not in ['id', 'projectId']}
                issuances_for_api.append(issuance_for_api)
            request_body['issuances'] = issuances_for_api
        else:

            request_body.pop('issuances', None)
        # request_body.pop('issuances', None)
        # print(issuances_for_api)
        
        # Remove the keys that are not needed for the POST request
        request_body.pop('country', None)
        request_body.pop('inCountryRegion', None)
        request_body.pop('geographicIdentifier', None)


        est = request_body['estimations'][0]
        # print(est)

        if est['creditingPeriodStart']== None or est['creditingPeriodEnd']==None:
            request_body.pop('estimations', None)

        # if request_body['country']=='NA':
        #     request_body['country']= "Namibia"

        # print(request_body)
        # Send POST request
        try:
            if type=="create":
                response = requests.post(url, json=request_body)
                # Check if the request was successful
            if type=="put":
                warehouseId = id_mapping[request_body['projectId']]
                print(warehouseId)
                request_body['warehouseProjectId'] =warehouseId
                response =requests.put(url,json=request_body)
            
            if response.status_code == 200:
                response_data = response.json()
                print(i)
                print(f"Successfully posted project with ID: {row['projectId']}, UUID: {response_data.get('uuid')}")
                
            else:
                print("i is",i)
                print(request_body)
                print(f"Failed to post project with ID: {row['projectId']}. Status code: {response.status_code}. Message: {response.json()}")
                break
        

        except RequestException as e:
            print(request_body)
            print(f"Request failed for project with ID:{row['projectId']}. Error: {e}")
            break

        i+=1
    return project_to_uuid_mapping
# Call the function to start posting data

def put_project(df,start_idx,end_idx,url):
    i=0
    for index, row in df[start_idx:end_idx].iterrows():
    
        request_body = row.to_dict()
        request_body = {k: datetime_to_string(v) for k, v in row.to_dict().items()}

   
        issuance_ids = []
        issuances_for_api = []

        # Uncomment Later 
        if row.get('issuances') is not None and isinstance(row.get('issuances'), list):
            for issuance in row.get('issuances', []):
                # Store the 'id' for later use
                issuance_id = issuance.get('id')
                issuance_ids.append(issuance_id)
                
                # Remove 'id' from the issuance data sent to the API
                issuance_for_api = {key: value for key, value in issuance.items() if key not in ['orgUid']}
                issuances_for_api.append(issuance_for_api)
            request_body['issuances'] = issuances_for_api
        else:

            request_body.pop('issuances', None)
        request_body['projectLocations'] = [{k: v for k, v in location.items() if k not in ['orgUid', 'warehouseProjectId']} for location in request_body['projectLocations'] ]
        try:
            response =requests.put(url,json=request_body)
            
            if response.status_code == 200:
                response_data = response.json()
                print(f"Successfully posted project with ID: {row['projectId']},")
                
            else:
                print("i is",i)
                print(request_body)
                print(f"Failed to post project with ID: {row['originProjectId']}. Status code: {response.status_code}. Message: {response.json()}")
                break
        
        except RequestException as e:
            print(request_body)
            print(f"Request failed for project with ID: {row['originProjectId']}. Error: {e}")
            break

        i+=1

        
    


merged_project_issuances = pd.merge(df_cleaned_project, issuances_grouped, on='projectId', how='left')

# df_project

url_staging_local = "http://localhost:31310/v1/staging"
url_staging_testnet = "http://159.223.67.223:31310/v1/staging"

def get_projects_staging_uuid(url):
    # url = "http://localhost:31310/v1/staging"

    # Make a GET request
    response = requests.get(url)

    
    # Check the response status code
    if response.status_code == 200:
        # The request was successful, and you can access the response content
        projects = response.json()
        project_id_to_uuid = {}
        project_id_to_issuances={}
        project_id_to_locationId={}
        for project in projects:

            uuid = project['uuid']
            # print(uuid)
            projectId = project['diff']['change'][0]['projectId']
            project_id_to_uuid[projectId] = uuid
            issuances = project['diff']['change'][0].get('issuances', None)

            

        # print(uuid_to_project_id)
        return project_id_to_uuid, project_id_to_issuances
    else:
        # The request failed for some reason
        print(f"Request failed with status code {response.status_code}")


def get_projects_mapping(base_url,orgUid):
    # Check if the specified conditions are met

    # base_url = "http://localhost:31310/v1/projects"
    page = 1
    limit = 100
    all_projects = []

    while True:
        print(page)
        
        url = f"{base_url}?page={page}&limit={limit}&orgUid={orgUid}"
        print(url)
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to retrieve data: {response.status_code}")
            break

        data = response.json()
        all_projects.extend(data['data'])
        # if page >= 1:
        if page >= data['pageCount']:
            break
        page += 1
    print("hah")
    
    projects = all_projects
    # print(projects)

    # response = requests.get(url+orgUid)
    # projects = response.json()
    # project_data = response.json()
    project_id_to_warehouseId = {}
    project_id_to_issuances={}
    project_id_to_locationId={}
    duplicate_projects = {}
    project_id_to_locations={}

    # print(projects[0])

    for project_data in projects:
        if (project_data["orgUid"] == orgUid and
            project_data["registryOfOrigin"] == "CDM Registry"):


            warehouseId = project_data["warehouseProjectId"]
            projectId = project_data["projectId"]
            # Mapping of 'projectId' and 'warehouseProjectId'
            if projectId not in project_id_to_warehouseId:
                project_id_to_warehouseId[projectId] = warehouseId

            else:
                duplicate_projects[projectId] = [project_id_to_warehouseId[projectId],warehouseId]
                project_id_to_warehouseId[projectId] = warehouseId
            
            # Mapping of 'projectId' and 'issuance' if 'issuance' exists
            issuance_ids = []
            issuances_for_api = []
        
            if project_data.get('issuances') is not None and isinstance(project_data.get('issuances'), list):
               
                for issuance in project_data.get('issuances', []):
                    # Store the 'id' for later use
                    issuance_id = issuance.get('id')
                    issuance_ids.append(issuance_id)
                    
                    # Remove 'id' from the issuance data sent to the API
                    issuance_for_api = {key: value for key, value in issuance.items() }
                    issuances_for_api.append(issuance_for_api)

                if issuances_for_api!= []:
                    project_id_to_issuances[projectId] = issuances_for_api

            # Mapping of 'projectId' and 'id' of 'projectLocations'
            locations_mapping = {}
            if project_data.get("projectLocations"):
                # print("lho")
                project_id_to_locationId[projectId]= project_data["projectLocations"][0]["id"]
                project_id_to_locations[projectId]= project_data["projectLocations"]

    return pd.DataFrame(all_projects), project_id_to_warehouseId, project_id_to_issuances, project_id_to_locationId,duplicate_projects,project_id_to_locations

        





# fail in project num 6142

# check if there is a same project but several uuid

# print(uuid_to_project_id_map)


# merged_project_issuances.to_excel("./output/ProjectsIssuancesCombined.xlsx")

# %%
# project_to_uuid_map,project_to_issuances = get_projects_staging_uuid(url_staging_testnet)

# print(len(project_to_uuid_map))


# Below is testnet"

orgUidTestnet = "fc7e4380bc8ba22f98a655e04b54af3aed122db34bb3357b3a9c3eb0ff7039bc"
orgUidMainnet = "b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985"

get_projects_url_local = "http://localhost:31310/v1/projects"

# Below is mainnet
# get_projects_url_local = "http://localhost:31310/v1/projects?orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985"

all_projects_api, project_id_to_warehouseId, issuance_mapping, locations_mapping,duplicate_projects_api,project_id_to_locations= get_projects_mapping(get_projects_url_local,orgUidMainnet)


print(len(project_id_to_warehouseId))
print(len(issuance_mapping))
print(len(locations_mapping))
print(len(duplicate_projects_api))
# Out:
# 1
# http://localhost:31310/v1/projects?page=1&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 2
# http://localhost:31310/v1/projects?page=2&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 3
# http://localhost:31310/v1/projects?page=3&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 4
# http://localhost:31310/v1/projects?page=4&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 5
# http://localhost:31310/v1/projects?page=5&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 6
# http://localhost:31310/v1/projects?page=6&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 7
# http://localhost:31310/v1/projects?page=7&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 8
# http://localhost:31310/v1/projects?page=8&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 9
# http://localhost:31310/v1/projects?page=9&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 10
# http://localhost:31310/v1/projects?page=10&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 11
# http://localhost:31310/v1/projects?page=11&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 12
# http://localhost:31310/v1/projects?page=12&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 13
# http://localhost:31310/v1/projects?page=13&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 14
# http://localhost:31310/v1/projects?page=14&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 15
# http://localhost:31310/v1/projects?page=15&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 16
# http://localhost:31310/v1/projects?page=16&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 17
# http://localhost:31310/v1/projects?page=17&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 18
# http://localhost:31310/v1/projects?page=18&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 19
# http://localhost:31310/v1/projects?page=19&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 20
# http://localhost:31310/v1/projects?page=20&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 21
# http://localhost:31310/v1/projects?page=21&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 22
# http://localhost:31310/v1/projects?page=22&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 23
# http://localhost:31310/v1/projects?page=23&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 24
# http://localhost:31310/v1/projects?page=24&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 25
# http://localhost:31310/v1/projects?page=25&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 26
# http://localhost:31310/v1/projects?page=26&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 27
# http://localhost:31310/v1/projects?page=27&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 28
# http://localhost:31310/v1/projects?page=28&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 29
# http://localhost:31310/v1/projects?page=29&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 30
# http://localhost:31310/v1/projects?page=30&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 31
# http://localhost:31310/v1/projects?page=31&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 32
# http://localhost:31310/v1/projects?page=32&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 33
# http://localhost:31310/v1/projects?page=33&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 34
# http://localhost:31310/v1/projects?page=34&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 35
# http://localhost:31310/v1/projects?page=35&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 36
# http://localhost:31310/v1/projects?page=36&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 37
# http://localhost:31310/v1/projects?page=37&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 38
# http://localhost:31310/v1/projects?page=38&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 39
# http://localhost:31310/v1/projects?page=39&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 40
# http://localhost:31310/v1/projects?page=40&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 41
# http://localhost:31310/v1/projects?page=41&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 42
# http://localhost:31310/v1/projects?page=42&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 43
# http://localhost:31310/v1/projects?page=43&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 44
# http://localhost:31310/v1/projects?page=44&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 45
# http://localhost:31310/v1/projects?page=45&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 46
# http://localhost:31310/v1/projects?page=46&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 47
# http://localhost:31310/v1/projects?page=47&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 48
# http://localhost:31310/v1/projects?page=48&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 49
# http://localhost:31310/v1/projects?page=49&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 50
# http://localhost:31310/v1/projects?page=50&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 51
# http://localhost:31310/v1/projects?page=51&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 52
# http://localhost:31310/v1/projects?page=52&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 53
# http://localhost:31310/v1/projects?page=53&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 54
# http://localhost:31310/v1/projects?page=54&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 55
# http://localhost:31310/v1/projects?page=55&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 56
# http://localhost:31310/v1/projects?page=56&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 57
# http://localhost:31310/v1/projects?page=57&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 58
# http://localhost:31310/v1/projects?page=58&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 59
# http://localhost:31310/v1/projects?page=59&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 60
# http://localhost:31310/v1/projects?page=60&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 61
# http://localhost:31310/v1/projects?page=61&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 62
# http://localhost:31310/v1/projects?page=62&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 63
# http://localhost:31310/v1/projects?page=63&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 64
# http://localhost:31310/v1/projects?page=64&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 65
# http://localhost:31310/v1/projects?page=65&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 66
# http://localhost:31310/v1/projects?page=66&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 67
# http://localhost:31310/v1/projects?page=67&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 68
# http://localhost:31310/v1/projects?page=68&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 69
# http://localhost:31310/v1/projects?page=69&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 70
# http://localhost:31310/v1/projects?page=70&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 71
# http://localhost:31310/v1/projects?page=71&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 72
# http://localhost:31310/v1/projects?page=72&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 73
# http://localhost:31310/v1/projects?page=73&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 74
# http://localhost:31310/v1/projects?page=74&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 75
# http://localhost:31310/v1/projects?page=75&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 76
# http://localhost:31310/v1/projects?page=76&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 77
# http://localhost:31310/v1/projects?page=77&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 78
# http://localhost:31310/v1/projects?page=78&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 79
# http://localhost:31310/v1/projects?page=79&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 80
# http://localhost:31310/v1/projects?page=80&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 81
# http://localhost:31310/v1/projects?page=81&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 82
# http://localhost:31310/v1/projects?page=82&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 83
# http://localhost:31310/v1/projects?page=83&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 84
# http://localhost:31310/v1/projects?page=84&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 85
# http://localhost:31310/v1/projects?page=85&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 86
# http://localhost:31310/v1/projects?page=86&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 87
# http://localhost:31310/v1/projects?page=87&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 88
# http://localhost:31310/v1/projects?page=88&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 89
# http://localhost:31310/v1/projects?page=89&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 90
# http://localhost:31310/v1/projects?page=90&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 91
# http://localhost:31310/v1/projects?page=91&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 92
# http://localhost:31310/v1/projects?page=92&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 93
# http://localhost:31310/v1/projects?page=93&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 94
# http://localhost:31310/v1/projects?page=94&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 95
# http://localhost:31310/v1/projects?page=95&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 96
# http://localhost:31310/v1/projects?page=96&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 97
# http://localhost:31310/v1/projects?page=97&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 98
# http://localhost:31310/v1/projects?page=98&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 99
# http://localhost:31310/v1/projects?page=99&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 100
# http://localhost:31310/v1/projects?page=100&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 101
# http://localhost:31310/v1/projects?page=101&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 102
# http://localhost:31310/v1/projects?page=102&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 103
# http://localhost:31310/v1/projects?page=103&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 104
# http://localhost:31310/v1/projects?page=104&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 105
# http://localhost:31310/v1/projects?page=105&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 106
# http://localhost:31310/v1/projects?page=106&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 107
# http://localhost:31310/v1/projects?page=107&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 108
# http://localhost:31310/v1/projects?page=108&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 109
# http://localhost:31310/v1/projects?page=109&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 110
# http://localhost:31310/v1/projects?page=110&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 111
# http://localhost:31310/v1/projects?page=111&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 112
# http://localhost:31310/v1/projects?page=112&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 113
# http://localhost:31310/v1/projects?page=113&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 114
# http://localhost:31310/v1/projects?page=114&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 115
# http://localhost:31310/v1/projects?page=115&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 116
# http://localhost:31310/v1/projects?page=116&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 117
# http://localhost:31310/v1/projects?page=117&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 118
# http://localhost:31310/v1/projects?page=118&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 119
# http://localhost:31310/v1/projects?page=119&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 120
# http://localhost:31310/v1/projects?page=120&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 121
# http://localhost:31310/v1/projects?page=121&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 122
# http://localhost:31310/v1/projects?page=122&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 123
# http://localhost:31310/v1/projects?page=123&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 124
# http://localhost:31310/v1/projects?page=124&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 125
# http://localhost:31310/v1/projects?page=125&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 126
# http://localhost:31310/v1/projects?page=126&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 127
# http://localhost:31310/v1/projects?page=127&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 128
# http://localhost:31310/v1/projects?page=128&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 129
# http://localhost:31310/v1/projects?page=129&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 130
# http://localhost:31310/v1/projects?page=130&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 131
# http://localhost:31310/v1/projects?page=131&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# 132
# http://localhost:31310/v1/projects?page=132&limit=100&orgUid=b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985
# hah
# 13154
# 3701
# 13154
# 0

# %%
print(len(project_id_to_warehouseId))
print(len(issuance_mapping))
print(len(locations_mapping))
print(len(duplicate_projects_api))
print(len(all_projects_api))




unique_proj_iss_before = issuances_grouped['projectId'].unique()

print("len unique cleaned Issuances before API",len(unique_proj_iss_before))
print("len cleaned Issuances before API",len(issuances_grouped))


# print("diff1",set((unique_proj_iss_before))-set((issuance_mapping)))
# print("diff2",set((issuance_mapping))-set((unique_proj_iss_before)))
print("len diff1",len(set((unique_proj_iss_before))-set((issuance_mapping))))
print("len diff2",len(set((issuance_mapping))-set((unique_proj_iss_before))))





delta_uploaded_issuances = set((unique_proj_iss_before))-set((issuance_mapping))

# for delta in delta_uploaded_issuances:
#     print(project_id_to_warehouseId[delta])


project_id_to_warehouseId["HG20LFVJPFURJJ4M6E6MS07HTOZTR4"]

# issuance_mapping
# issuances_grouped.to_excel("asdasd.xlsx")

# len(issuance_mapping['U2ODRRPWUQQ6QTZ7ZILTXXHF5971KB'])
temp = issuances_grouped[issuances_grouped['projectId']== 'HG20LFVJPFURJJ4M6E6MS07HTOZTR4']

temp['issuances']

# this function never been used
def get_warehouseId_and_update_issuances(delta_uploaded_issuances, project_id_to_warehouseId, issuances_grouped, specific_project_id):

    # Print warehouse IDs for each project ID in delta_uploaded_issuances
    for delta in delta_uploaded_issuances:
        if delta in project_id_to_warehouseId:
            print(project_id_to_warehouseId[delta])
        else:
            print(f"Warehouse ID not found for project ID: {delta}")

    # Get 'issuances' data for a specific project ID
    specific_issuances = issuances_grouped[issuances_grouped['projectId'] == specific_project_id]['issuances']
    # print(len(specific_issuances['issuances']))
    return specific_issuances

def concat_existing_new_issuances(issuance_from_api, issuance_to_add):
    # Create a new dictionary to hold the combined data
    new_issuance_data = {}

    # Iterate through each row in the DataFrame
    for index, row in issuance_to_add.iterrows():
        project_id = row['projectId']
        # Create a new list of issuances without 'projectId' and 'id' keys
        new_issuances = [{k: v for k, v in issuance.items() if k not in ['projectId', 'id']} for issuance in row['issuances']]
        # Check if the projectId exists in the original dictionary
       
        if project_id in issuance_from_api:
            # Concatenate the existing and new issuances

          
            combined_issuances = issuance_from_api[project_id] + new_issuances
        else:
            # Use only the new issuances
            combined_issuances = new_issuances


        # Update the new dictionary
        new_issuance_data[project_id] = combined_issuances

    return new_issuance_data

# def getAllCdmProjects(orgUid):
#     base_url = "http://localhost:31310/v1/projects"
#     page = 1
#     limit = 2000
#     all_projects = []

#     while True:
#         print(page)
#         url = f"{base_url}?page={page}&limit={limit}&orgUid={orgUid}"
#         response = requests.get(url)
#         if response.status_code != 200:
#             print(f"Failed to retrieve data: {response.status_code}")
#             break

#         data = response.json()
#         all_projects.extend(data['data'])

#         if page >= data['pageCount']:
#             break
#         page += 1

#     return pd.DataFrame(all_projects)

def clean_estimations(estimations):
    # This function takes a list of estimation dictionaries and removes the specified keys
    for estimation in estimations:
        estimation.pop('warehouseProjectId', None)  # Remove 'warehouseProjectId' if exists
        estimation.pop('orgUid', None)              # Remove 'orgUid' if exists
        estimation.pop('timeStaged', None)   
    return estimations

def clean_project_locations(locations):
    # This function takes a list of estimation dictionaries and removes the specified keys
    for location in locations:
        location.pop('warehouseProjectId', None)  # Remove 'warehouseProjectId' if exists
        location.pop('orgUid', None)        
        location.pop('timeStaged', None)        
        
              # Remove 'orgUid' if exists
    return locations



def updateNewIssuances(df,issuances_data,start,end,env):
    df_filtered = df[df['warehouseProjectId'].isin(issuances_data['warehouseProjectId'])]
    issuance_map = dict(zip(issuances_data['warehouseProjectId'], issuances_data['issuances']))
    df_filtered['issuances'] = df_filtered['warehouseProjectId'].map(issuance_map)
    # Apply the function to the 'estimations' column
    df_filtered['estimations'] = df_filtered['estimations'].apply(clean_estimations)
    df_filtered['projectLocations'] = df_filtered['projectLocations'].apply(clean_project_locations)
    df_filtered.drop("projectRatings",axis=1,inplace=True)
    df_filtered.drop("labels",axis=1,inplace=True)
    df_filtered.drop("relatedProjects",axis=1,inplace=True)
    df_filtered.drop("coBenefits",axis=1,inplace=True)
    # if env=="testnet":
    df_filtered.drop("timeStaged",axis=1,inplace=True)
  
    
    
    
    
    
    i=0
    # dropping_columns = ["labels","relatedProjects","createdAt","updatedAt","orgUid"]
    for index, row in df_filtered[start:end].iterrows():
    
        request_body = row.to_dict()
        request_body = {k: datetime_to_string(v) for k, v in row.to_dict().items()}

        request_body.pop('orgUid', None)
        


        issuance_ids = []
        issuances_for_api = []


        # Uncomment Later 
        if row.get('issuances') is not None and isinstance(row.get('issuances'), list):
            for issuance in row.get('issuances', []):
                # Store the 'id' for later use
                issuance_id = issuance.get('id')
                issuance_ids.append(issuance_id)
                
                # Remove 'id' from the issuance data sent to the API
                issuance_for_api = {key: value for key, value in issuance.items() if key not in [ 'orgUid','projectId','timeStaged']}
                issuances_for_api.append(issuance_for_api)
            request_body['issuances'] = issuances_for_api
        else:

            request_body.pop('issuances', None)

        if env=="testnet":
            request_body.pop('estimations', None)
           

        try:
            urlPut = "http://localhost:31310/v1/projects"
            response = requests.put(urlPut, json=request_body)
           
            if response.status_code == 200:
                response_data = response.json()
                print(i)
                print(f"Successfully posted project with ID: {row['warehouseProjectId']}")
                
            else:
                print("i is",i)
                print(request_body)
                print(f"Failed to post project with ID: {row['warehouseProjectId']}. Status code: {response.status_code}. Message: {response.json()}")
                break
        

        except RequestException as e:
            print(request_body)
            print(f"Request failed for project with ID:{row['warehouseProjectId']}. Error: {e}")
            break

        i+=1
        
    



    return df_filtered



    


issuance_for_api_PUT = concat_existing_new_issuances(issuance_mapping,issuances_grouped)

print(len(set(issuance_for_api_PUT)))
# print(issuance_for_api_PUT)

data = list(issuance_for_api_PUT.items())

# Create DataFrame from the list of tuples
df_issuances_extended = pd.DataFrame(data, columns=['projectId', 'issuances'])

# Display the DataFrame
df_issuances_extended['warehouseProjectId']= df_issuances_extended['projectId'].map(project_id_to_warehouseId)

print(len(df_issuances_extended['warehouseProjectId'].unique()))
df_issuances_extended
# Out:
# 13154
# 3701
# 13154
# 0
# 13154
# len unique cleaned Issuances before API 3564
# len cleaned Issuances before API 3564
# len diff1 0
# len diff2 137
# 3564
# 3564
#                            projectId  \
# 0     00J4UE52C4VTT01JSVE9ERDU8WP76W
# 1     00MPVBXC6YBLA33C1NN1G3K33VHK1V
# 2     015ESW8TY1JO2B2E0T0EP4ZZQKQM5D
# 3     01BHKDBIJYIMU1ZSLWRZX238VM5FJU
# 4     01GN1N0RHE2KY6CRDPWDNY7ELCZKNT
# ...                              ...
# 3559  ZYXH65I6FVRCHO68AS8K64WYFS3V2O
# 3560  ZZ2UA0ANWJAF7LL3BE60P5HG1LRLAJ
# 3561  ZZ99SW9AQ4MM9WTA4H7WGK2IQZ9BZK
# 3562  ZZK6XB1XUWV596IZZ4H06G6E9KBC1G
# 3563  ZZKS904BYTBWYDDITR4TN1CEWCUDAX
#
#                                               issuances  \
# 0     [{'id': '5cf0f806-3a3b-4d3d-a358-4d8ba1dfaa01'...
# 1     [{'id': '4dc1abb3-ad70-4351-9a17-df8ff387b083'...
# 2     [{'id': '18577b0a-2034-44c1-8fdb-63c6a6129f9d'...
# 3     [{'id': '8fa84163-c76b-41e4-9760-7ad973d51a7d'...
# 4     [{'id': '203a4bb2-703d-4218-a9e4-a43618b28104'...
# ...                                                 ...
# 3559  [{'id': '652efe4c-fa4c-458e-b5d9-6e01dd5963fe'...
# 3560  [{'id': '1bce1ea2-0324-4018-bcce-d35338b2551a'...
# 3561  [{'id': '44095342-edcc-48f0-8726-c6774e4e391d'...
# 3562  [{'id': '29385476-6772-4ec6-afa9-ee15e1738cff'...
# 3563  [{'id': '62742f5c-8a6e-4c84-8282-3dfff76a5e76'...
#
#                         warehouseProjectId
# 0     d9716c37-3370-4903-bf0b-6bad99c015f0
# 1     d6e80c17-6719-44e2-9687-e884780340cc
# 2     e98e1327-b1b9-4481-94c3-8565023d5187
# 3     ce055d32-4d09-41f2-a6af-9ecd5edf28ec
# 4     7f111e3e-f509-4ee8-a144-ef949d41ec85
# ...                                    ...
# 3559  ec130a9b-d7c9-4058-9602-73fd35abef2e
# 3560  ea42ba32-a0d1-49fd-98dc-08b6d1407296
# 3561  70f9b392-e350-42e2-81d9-34af6af607d0
# 3562  64489a48-62aa-4640-b953-8976a4c9a31a
# 3563  1c39a537-7ce4-4458-82c1-64f8c5eaa4bd
#
# [3564 rows x 3 columns]

# %%
# orgUidMainnet = "b3d4e71d806e86ff1f8712b6854d65e2c178e873ee22b2f7d0da937dacbaa985"
# orgUidTestnet = "fc7e4380bc8ba22f98a655e04b54af3aed122db34bb3357b3a9c3eb0ff7039bc"
# all_api = getAllCdmProjects(orgUidMainnet)
# len(all_api)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 13154

# %%
# Comment if we want to update
# issuances_ext = updateNewIssuances(all_projects_api,df_issuances_extended,3400,3600,"mainnet")
# issuances_ext.to_excel("testtest_hu_2.xlsx")
# Out:
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['issuances'] = df_filtered['warehouseProjectId'].map(issuance_map)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['estimations'] = df_filtered['estimations'].apply(clean_estimations)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['projectLocations'] = df_filtered['projectLocations'].apply(clean_project_locations)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop("projectRatings",axis=1,inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop("labels",axis=1,inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop("relatedProjects",axis=1,inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop("coBenefits",axis=1,inplace=True)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3629/3454799427.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop("timeStaged",axis=1,inplace=True)
# 0
# Successfully posted project with ID: 84e0dfdc-27d5-411a-83b5-d65c420dfc08
# 1
# Successfully posted project with ID: 3bcfe4db-504f-4ee7-84b7-a3539f228fdf
# 2
# Successfully posted project with ID: ed252d0a-1411-477b-9ab9-ed96fa525902
# 3
# Successfully posted project with ID: 3d7705b0-6e86-4dea-8b5b-f38ab6e9932a
# 4
# Successfully posted project with ID: 66f5a852-6231-47d6-b504-7f8f7eb4af6a
# 5
# Successfully posted project with ID: 71456b6f-8b34-4496-b589-555c641c0d75
# 6
# Successfully posted project with ID: 52f78976-a736-442b-8c8b-e9e9505d636d
# 7
# Successfully posted project with ID: d722b048-9d30-4c25-9d1d-ddaf0ad1c890
# 8
# Successfully posted project with ID: 975d805a-458b-4d6d-aa6c-af59fcfa0a06
# 9
# Successfully posted project with ID: 91d5d21d-c0fe-40b0-a3a5-895f7e13a773
# 10
# Successfully posted project with ID: 72fd65bd-3a49-4ab4-8b02-c9e8c9350909
# 11
# Successfully posted project with ID: 461c82fe-8e69-4801-b658-136819f717c1
# 12
# Successfully posted project with ID: af8f0337-becb-4543-b4fb-5f8263208d39
# 13
# Successfully posted project with ID: df633325-3445-457a-a5fa-02957a2bffe0
# 14
# Successfully posted project with ID: 8541b097-b519-4753-9792-576036f912f7
# 15
# Successfully posted project with ID: 4aa86074-ef8e-4e4b-8d21-d6ed94153e45
# 16
# Successfully posted project with ID: 41f8b8fa-c0f4-4617-bb24-913e092c5166
# 17
# Successfully posted project with ID: 62a9aea4-c4cc-4640-9b78-bcc272e4bd0b
# 18
# Successfully posted project with ID: 63079dda-f437-4059-a344-1a462bc3eb8b
# 19
# Successfully posted project with ID: 9be1d0dc-3917-43b3-96f9-ee68143dd08b
# 20
# Successfully posted project with ID: 1903682b-2758-4733-a967-0759b8605661
# 21
# Successfully posted project with ID: c67a2f7d-b6bb-4824-8a27-f2a90d65ecc9
# 22
# Successfully posted project with ID: d1482eef-c995-4394-b1d2-599673006714
# 23
# Successfully posted project with ID: 72579474-bf57-482c-9e55-3a7c94c7d2be
# 24
# Successfully posted project with ID: 5719c2a7-0129-425e-88e4-f35f78c1d98f
# 25
# Successfully posted project with ID: 9c53ba27-ed5f-4a2b-8792-afb5e77c5d21
# 26
# Successfully posted project with ID: 02eba963-4826-4fd3-975a-f8ee37e3d8be
# 27
# Successfully posted project with ID: 2cfc73f1-b75c-4f57-9aec-86c68515ddb6
# 28
# Successfully posted project with ID: fbe155a6-7a2e-48d9-85be-1b6235badc6f
# 29
# Successfully posted project with ID: e31f6f0a-7e84-465c-83c7-4e4d6629392e
# 30
# Successfully posted project with ID: d770d412-23a0-4248-804e-29d9dde534e6
# 31
# Successfully posted project with ID: 42685e8c-e88a-4f60-9e26-6ff8d80d4053
# 32
# Successfully posted project with ID: 345ec79d-5e07-403e-9c31-586a1054778e
# 33
# Successfully posted project with ID: 64ad25de-0608-4df5-a5f0-163b84bb227f
# 34
# Successfully posted project with ID: e7ec14c4-a894-4f1d-885c-18ca7f3e62da
# 35
# Successfully posted project with ID: e4776f2b-fee9-4305-b1bc-2d9f1e9fc54c
# 36
# Successfully posted project with ID: 6653b8fa-5780-48ba-806c-3e1a9050e6ff
# 37
# Successfully posted project with ID: 697cc264-45de-486d-9405-664b8467ad62
# 38
# Successfully posted project with ID: fd436587-928c-4d72-8237-7a8892db8b6f
# 39
# Successfully posted project with ID: 862a0100-7b7f-43ab-ae4f-1ac1c5a0eb83
# 40
# Successfully posted project with ID: e2548e53-ca12-4290-8754-20a528c17420
# 41
# Successfully posted project with ID: d6b5bd1d-52c4-440e-b206-d8675fa1bfe8
# 42
# Successfully posted project with ID: b8555ada-a0f3-4e25-a4ec-98135316c0d9
# 43
# Successfully posted project with ID: 417d0dce-d065-4908-85c0-73621193bc06
# 44
# Successfully posted project with ID: 7495df2f-b3c8-4730-808e-a778f6f2b58a
# 45
# Successfully posted project with ID: 25a84d29-1555-4f0d-907e-c211ec5c8edf
# 46
# Successfully posted project with ID: 74b628bb-edfd-430c-aa74-cf5b35979e0b
# 47
# Successfully posted project with ID: 60a563fc-238a-4785-8260-8559384c360e
# 48
# Successfully posted project with ID: c6a64add-e7f6-4ffe-aed0-581e8ef72333
# 49
# Successfully posted project with ID: 29494c71-6afa-4427-953a-87f8ccf45b67
# 50
# Successfully posted project with ID: 3a945876-04b2-4006-89a1-1546cc432e5a
# 51
# Successfully posted project with ID: 9d1196e8-9596-4b77-852a-5605399ec7bb
# 52
# Successfully posted project with ID: 6572640c-12c3-467a-b263-ef66676983b9
# 53
# Successfully posted project with ID: aeaaab32-5a17-4998-9419-1ce5bb9314a1
# 54
# Successfully posted project with ID: 70c64c04-2e9f-425e-a77c-9f45f2e0c803
# 55
# Successfully posted project with ID: 46f74037-849b-4e52-b268-b38e06615218
# 56
# Successfully posted project with ID: 4b6505f5-5adb-429e-af6b-da87e883dccf
# 57
# Successfully posted project with ID: b3a1a3cc-4972-4999-86af-4a5f7a9355df
# 58
# Successfully posted project with ID: 6dd47958-545c-44c0-be2a-ad007575346b
# 59
# Successfully posted project with ID: 7ae4aa3d-c13d-48b8-baab-dd179542e0ea
# 60
# Successfully posted project with ID: 96668a0c-2dfc-4abc-a65c-b27c5bcdadae
# 61
# Successfully posted project with ID: 724c78c8-fe06-44c5-bfba-32a27208e4ae
# 62
# Successfully posted project with ID: 35664ece-e78d-4d57-9bc3-10e05b5ed850
# 63
# Successfully posted project with ID: f48576a9-16a6-4363-bc63-33ec05bdacc8
# 64
# Successfully posted project with ID: 838b276a-bc84-472e-926d-69e35298e46f
# 65
# Successfully posted project with ID: 87df179f-f120-468c-aa9c-7ca5f747b147
# 66
# Successfully posted project with ID: 16175f15-6d15-4322-92ea-850fe2f52957
# 67
# Successfully posted project with ID: 3c1bb46d-b7a7-4b6e-bf15-74f80c51683f
# 68
# Successfully posted project with ID: f65deb6c-600a-4327-a20b-7a91c366bb4e
# 69
# Successfully posted project with ID: 56444413-b256-4856-aca5-9fb4e9abffed
# 70
# Successfully posted project with ID: a605c039-8073-46e1-888d-981211d18f8b
# 71
# Successfully posted project with ID: 4e952c1e-0ec1-4469-8ce9-b61bf594b597
# 72
# Successfully posted project with ID: ea03379e-0c16-4b72-a936-99c2b3431389
# 73
# Successfully posted project with ID: 58285ec8-568c-4927-909c-3f875684a12b
# 74
# Successfully posted project with ID: e99b2ba6-23b4-4613-9087-d766291a01f7
# 75
# Successfully posted project with ID: cf3102f1-764b-44f6-8d20-155111d65b05
# 76
# Successfully posted project with ID: ffdbc673-0990-41ba-b7c6-af05bf51a201
# 77
# Successfully posted project with ID: 6e5f9861-2c8c-4c76-a302-bb32f22e08cf
# 78
# Successfully posted project with ID: cb05264a-0f87-4e4a-808b-247693595937
# 79
# Successfully posted project with ID: e547b291-e57d-4f68-93a4-dd1b955fa48a
# 80
# Successfully posted project with ID: 29946354-b241-4c51-92ce-d4203aa36cbb
# 81
# Successfully posted project with ID: d9da5841-4008-41f2-aa8c-88f714cb1c10
# 82
# Successfully posted project with ID: c07e7790-a018-4820-b4a5-d77d41c085b2
# 83
# Successfully posted project with ID: 94c27a80-b090-444c-96b3-2924a3c0fab1
# 84
# Successfully posted project with ID: 0aec1006-9101-4e13-83b2-478fd9d66503
# 85
# Successfully posted project with ID: 1dc06fe8-337d-46bd-9ea3-e4d96205c9c2
# 86
# Successfully posted project with ID: 16f2a600-79c2-4730-86e9-aaddbf2e8665
# 87
# Successfully posted project with ID: 7a2e8ab4-29c0-42a8-b0f6-2b61564a504c
# 88
# Successfully posted project with ID: a52fb2bd-cffc-48ba-92be-06e0653527b3
# 89
# Successfully posted project with ID: 777a87ac-19db-456d-9235-904df2a68bbd
# 90
# Successfully posted project with ID: 55642128-8379-4a4a-a86a-c8b035024c51
# 91
# Successfully posted project with ID: a4c20780-341f-4633-8b86-e3d4099139e2
# 92
# Successfully posted project with ID: da099299-3a2e-414f-bfac-f2d42973cbbe
# 93
# Successfully posted project with ID: f82f7f99-673f-4689-99be-a7a877fd7863
# 94
# Successfully posted project with ID: 0980f123-489f-4a0f-808c-7a51a100f82b
# 95
# Successfully posted project with ID: d9741fad-ffc4-46a7-941f-dda639b09c4f
# 96
# Successfully posted project with ID: 6e575aea-4bb3-42c8-a2ba-22456855559a
# 97
# Successfully posted project with ID: 36306bc6-9c1b-4e34-a54c-2db690bafb8b
# 98
# Successfully posted project with ID: e60a2a5a-48d6-491c-869e-401722a8651c
# 99
# Successfully posted project with ID: 3ce62c73-6731-46ee-abf5-c1da682471ae
# 100
# Successfully posted project with ID: b92d9dbe-5496-4da3-b21e-1ac86dc5dda0
# 101
# Successfully posted project with ID: 83e39d34-cdf3-4290-b849-bb2eaabf1971
# 102
# Successfully posted project with ID: 43a5d826-ca50-4b39-b315-8701e362602a
# 103
# Successfully posted project with ID: 2fa974c0-0f76-403f-81b5-129bcd0d091c
# 104
# Successfully posted project with ID: 8729010c-35a5-4809-822c-507e83083478
# 105
# Successfully posted project with ID: 84b7d2fd-dd4c-4a65-8b31-0b526728fa73
# 106
# Successfully posted project with ID: d26b2cdc-0b00-4aec-aa48-a7c127b0bf3a
# 107
# Successfully posted project with ID: 5b49a980-e14d-4836-8a75-3e93d9d56a11
# 108
# Successfully posted project with ID: 31b0c798-183e-40ad-b2ab-7e4285ad95d9
# 109
# Successfully posted project with ID: a7f2216c-f842-49e5-89f7-208df0509bfc
# 110
# Successfully posted project with ID: cd52fdd9-3a61-4d9f-a1c8-ee9e306b5dd2
# 111
# Successfully posted project with ID: 561c63a9-956c-4c50-afcf-326f8508067f
# 112
# Successfully posted project with ID: ee630833-9c34-49c1-8996-94bbb0fd45e9
# 113
# Successfully posted project with ID: 973ca8ad-c6c4-4538-ac7c-661f762218cf
# 114
# Successfully posted project with ID: b93420bc-b361-4f51-b37e-2b23cc9142b9
# 115
# Successfully posted project with ID: 40fe771f-b44e-46b4-afd7-5a198389dc02
# 116
# Successfully posted project with ID: 87b5acc7-8719-4c88-b9b6-270453c4b6dd
# 117
# Successfully posted project with ID: 16f51d9e-b561-45ad-88cc-47b422a05698
# 118
# Successfully posted project with ID: 5f86a916-b3ba-4c88-9019-ed5de69a3aa8
# 119
# Successfully posted project with ID: 82799fd4-c13e-4fca-ad40-2a11d0463b93
# 120
# Successfully posted project with ID: 4c905845-cd86-43eb-8c56-9b4874ce5cb0
# 121
# Successfully posted project with ID: f463b2fe-1349-499f-a626-327ee496b14a
# 122
# Successfully posted project with ID: 6460da2c-ad81-4cce-9ffa-9d9590f11ea7
# 123
# Successfully posted project with ID: 09a647d5-0394-4a47-952b-48b15f0d315c
# 124
# Successfully posted project with ID: 486f1a54-5587-4baf-87dc-47e56e5a8e67
# 125
# Successfully posted project with ID: 5ef2f393-d1b8-4873-ab96-a6ebca1bfc0a
# 126
# Successfully posted project with ID: f98e0cd3-cdac-40a0-b9b9-3a8e4b615faa
# 127
# Successfully posted project with ID: 57cdb9e8-50e4-404f-a00c-b7c42ed380dd
# 128
# Successfully posted project with ID: e751eef3-6030-4131-97e5-18e482a55b31
# 129
# Successfully posted project with ID: 110e38fe-0f80-4d3c-aa43-a6436110dc34
# 130
# Successfully posted project with ID: 465658ff-b579-4d8a-9100-ecc5fe37605c
# 131
# Successfully posted project with ID: eead0603-50bb-45a7-ab2a-2bb86770a703
# 132
# Successfully posted project with ID: effba408-5f1b-4f97-9f45-cd97210aa1d0
# 133
# Successfully posted project with ID: 696e6752-bbce-49e2-b2de-6d87672ec6c8
# 134
# Successfully posted project with ID: 1c578a3e-b0a2-468b-aa4c-5c11acd88618
# 135
# Successfully posted project with ID: 2530b412-7bcb-4209-8dc8-a8c73e18bdf4
# 136
# Successfully posted project with ID: 56c07951-3872-4037-a62b-88ac021e12c4
# 137
# Successfully posted project with ID: ccc2fcd7-6c61-4013-8d86-6ead80956e41
# 138
# Successfully posted project with ID: 53c45d0e-009e-44bf-80a7-a1a51e1e833c
# 139
# Successfully posted project with ID: bebb3c65-d9fe-4afe-ae64-b9d149ef3feb
# 140
# Successfully posted project with ID: fc3b3a81-d104-46b3-886f-138b4d328ebc
# 141
# Successfully posted project with ID: 77d287e1-d574-4b35-87e0-130e705a50f0
# 142
# Successfully posted project with ID: 88aa6fef-ffb8-48ab-a926-99186c3c4690
# 143
# Successfully posted project with ID: 5120b7ae-893d-4c39-ac05-b196323dc89f
# 144
# Successfully posted project with ID: 054ca9bd-ab42-4cba-9ae4-4988efe4a79a
# 145
# Successfully posted project with ID: e572a846-def1-48c3-9d15-e2ea4e404d4d
# 146
# Successfully posted project with ID: 702f64fd-f529-4d59-b999-52eb36ed093f
# 147
# Successfully posted project with ID: 8bfc6ec7-349e-4882-b3b5-524a19c0cb74
# 148
# Successfully posted project with ID: ec1b913a-a7b9-48de-87dd-6b7b15884aab
# 149
# Successfully posted project with ID: 822d12e1-9271-4720-b69a-8662b23a3a74
# 150
# Successfully posted project with ID: ee9580fb-821e-468f-a881-7377e2a9da46
# 151
# Successfully posted project with ID: 26e8bfbd-6a2f-4b4d-8fea-a874605284c2
# 152
# Successfully posted project with ID: a3d98e7d-4468-44a2-a6b9-fa157fcf4d18
# 153
# Successfully posted project with ID: 717db20d-85ab-4e45-9f84-e5f31c0ab120
# 154
# Successfully posted project with ID: 7a82a131-063e-4110-b417-677b63691432
# 155
# Successfully posted project with ID: 56e2d4b4-2779-4e52-82e2-d4ff40bc39eb
# 156
# Successfully posted project with ID: 97bbaa9e-c798-4651-9040-e8888beb5438
# 157
# Successfully posted project with ID: d67ed3aa-000d-4bcf-9f30-93fb80c00bfc
# 158
# Successfully posted project with ID: d1d26c06-842b-4fc0-9574-ec08c21534d1
# 159
# Successfully posted project with ID: 888af006-2807-42a7-88ac-2ab482382140
# 160
# Successfully posted project with ID: ece0e34b-a201-43f3-b8e3-8b709cd96381
# 161
# Successfully posted project with ID: 7e68ab9f-1d55-4557-a666-56814658d037
# 162
# Successfully posted project with ID: ef3e53f3-bde6-41fd-9841-9f2ca61464a8
# 163
# Successfully posted project with ID: ab06a7b7-cc85-41f1-a6c2-da34d4243863

# %%
# try update issuance of first 10 projects

# def testnet_update_10_issuances_bef_2016(all_api,df_issuances_new):
#     # ONLY DO THIS IN TESTNET
#     # all_api.drop("estimations", axis=1, inplace=True)
#     issuances_ext = updateNewIssuances(all_api,df_issuances_new,0,10,"testnet")

# update_first_10_issuances = testnet_update_10_issuances_bef_2016(all_api,df_issuances_extended)



# def units_belong_to_first_10(df_issuances,retired_units):
#     first_10 = df_issuances[0:10]

#     df_retired_units_in_first_10 =retired_units[retired_units['projectId'].isin( first_10['projectId'])]
#     return df_retired_units_in_first_10

# df_retired_first_10 = units_belong_to_first_10(all_api,df_issuances_extended)
# df_retired_first_10
# Out:
#                            projectId  \
# 1681  HG20LFVJPFURJJ4M6E6MS07HTOZTR4
#
#                                               issuances  \
# 1681  [{'id': '437a1b0b-2263-4484-ad67-a0e569cdea64'...
#
#                         warehouseProjectId
# 1681  fed3d1e8-d218-4d4f-8f10-b4aa02d21704

# %%
# def process_projects(project_issuances, locations_mapping, project_id_to_warehouseId, issuance_mapping, project_id_to_locations,start,end):
#     # Select the first 100 projects
#     first_100_projects = project_issuances[start:end]

#     # Map additional information to the projects using the provided mappings
#     first_100_projects['warehouseProjectId'] = first_100_projects['projectId'].map(project_id_to_warehouseId)
#     first_100_projects['issuances'] = first_100_projects['projectId'].map(issuance_mapping)
#     first_100_projects['projectLocations'] = first_100_projects['projectId'].map(project_id_to_locations)

#     # Define columns to drop
#     projects_column_to_drop = ['country', 'inCountryRegion', 'geographicIdentifier']

#     # Drop the specified columns
#     first_100_projects = first_100_projects.drop(columns=projects_column_to_drop)

#     # Return the processed dataframe
#     return first_100_projects

# # first_100_projects = process_projects(merged_project_issuances, locations_mapping, project_id_to_warehouseId, issuance_mapping, project_id_to_locations)
# # first_100_projects.to_excel("First_100_projects.xlsx")

# processed_new_issuances =process_projects(merged_project_issuances, locations_mapping, project_id_to_warehouseId, issuance_mapping, project_id_to_locations,0,50000)
# processed_new_issuances.to_excel("see_new_added_iss.xlsx")
# Out:
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3913/3719153048.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_100_projects['warehouseProjectId'] = first_100_projects['projectId'].map(project_id_to_warehouseId)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3913/3719153048.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_100_projects['issuances'] = first_100_projects['projectId'].map(issuance_mapping)
# /var/folders/5x/w7k9bsls4fj7q9x5f3xxvt5m0000gn/T/ipykernel_3913/3719153048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_100_projects['projectLocations'] = first_100_projects['projectId'].map(project_id_to_locations)

# %%
# will do 9000 to 1000
# post_projects(merged_project_issuances,12600,13000,url_project_local,"create","ok","ok")

# %%
df_retired_clean
# Out:
#        unitStatus  unitCount unitOwner                       projectId  \
# 0         Retired       5294    Brazil  DWXTGTQLAORUROS9KPVZJUSGI8UK70
# 6         Retired       5294    Brazil  8J911GX7NLREEIL5L09MKJTI9USERE
# 18        Retired       5000    Brazil  O5C8ZV4YZTL3001AX5RD5V1OL5OM0A
# 36        Retired       5000    Brazil  HY2WB5CJ5DZTLBFLQE55ZHT0XK2DO2
# 43        Retired       5000    Brazil  0IET49KTMORLOP6NX7Q56DF7HXTMPV
# ...           ...        ...       ...                             ...
# 130472    Retired          3     Chile  L9H0347KVT9F7MAMD49TAYUJLMFHEW
# 130476    Retired          1     China  B90WLUX8QKF2591LN21LEVJ82HOO75
# 130478    Retired        186    Malawi  YHNSTOHUC3NLV2APHHB6SCWA61Q46T
# 130479    Retired        129     India  82ORS4DFFAE3F7JI64VMOSYQEYXGCB
# 130482    Retired       1677    Malawi  G8WF6TLTG80XJCQJCZOIX6XI7WDNZ9
#
#         unitBlockStart  unitBlockEnd countryJurisdictionOfOwner  \
# 0             65142364      65147657                     Brazil
# 6             60482913      60488206                     Brazil
# 18            57297956      57302955                     Brazil
# 36            61682096      61687095                     Brazil
# 43            57923146      57928145                     Brazil
# ...                ...           ...                        ...
# 130472        41951955      41951957                      Chile
# 130476      1185996159    1185996159                      China
# 130478          207935        208120                     Malawi
# 130479       279636945     279637073                      India
# 130482          362561        364237                     Malawi
#
#        inCountryJurisdictionOfOwner unitType  \
# 0
# 6
# 18
# 36
# 43
# ...                             ...      ...
# 130472
# 130476
# 130478
# 130479
# 130482
#
#        correspondingAdjustmentDeclaration  \
# 0                                 Unknown
# 6                                 Unknown
# 18                                Unknown
# 36                                Unknown
# 43                                Unknown
# ...                                   ...
# 130472                            Unknown
# 130476                            Unknown
# 130478                            Unknown
# 130479                            Unknown
# 130482                            Unknown
#
#                                          unitRegistryLink verificationBody  \
# 0       https://cdm.unfccc.int/Projects/Validation/DB/...             RINA
# 6       https://cdm.unfccc.int/Projects/Validation/DB/...         TUV NORD
# 18      https://cdm.unfccc.int/Projects/Validation/DB/...              DNV
# 36      https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
# 43      https://cdm.unfccc.int/Projects/Validation/DB/...              DNV
# ...                                                   ...              ...
# 130472  https://cdm.unfccc.int/Projects/Validation/DB/...         TUV NORD
# 130476  https://cdm.unfccc.int/Projects/Validation/DB/...             LGAI
# 130478  https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
# 130479  https://cdm.unfccc.int/Projects/Validation/DB/...             LGAI
# 130482  https://cdm.unfccc.int/Projects/Validation/DB/...          TUV SUD
#
#                                    geographyIdentifier  vintageYear  \
# 0        {"latitude":-14.235004,"longitude":-51.92528}         2005
# 6        {"latitude":-14.235004,"longitude":-51.92528}         2010
# 18       {"latitude":-14.235004,"longitude":-51.92528}         2006
# 36       {"latitude":-14.235004,"longitude":-51.92528}         2011
# 43       {"latitude":-14.235004,"longitude":-51.92528}         2008
# ...                                                ...          ...
# 130472  {"latitude":-35.675147,"longitude":-71.542969}         2013
# 130476    {"latitude":35.86166,"longitude":104.195397}         2013
# 130478   {"latitude":-13.254308,"longitude":34.301525}         2014
# 130479     {"latitude":20.593684,"longitude":78.96288}         2015
# 130482   {"latitude":-13.254308,"longitude":34.301525}         2015
#
#                             id
# 0         DNV-CUK1293110659.42
# 6          DNV-CUK1299845791.9
# 18        DNV-CUK1264416604.37
# 36      TUEV-SUED1317711892.85
# 43        DNV-CUK1265191517.98
# ...                        ...
# 130472     Applus1654182155.66
# 130476   Applus1654080342.92-2
# 130478  TUEV-SUED1446721135.84
# 130479   Applus1557750802.84-1
# 130482       ESPL1478153711.44
#
# [24357 rows x 15 columns]

# %%
df_retired_clean

def safe_convert_to_datetime_format(date_str):
    try:
        return pd.to_datetime(date_str).strftime('%Y-%m-%dT%H:%M:%S.000Z')
    except (pd.errors.OutOfBoundsDatetime, ValueError):
        return None 
        
def match_uploaded_issuance(row):
    
    for uploaded in row['uploadedIssuance']:
        start_date = safe_convert_to_datetime_format(row['startDate'])
        end_date = safe_convert_to_datetime_format(row['endDate'])


        # start_date = pd.to_datetime(row['startDate']).strftime('%Y-%m-%dT%H:%M:%S.000Z')
        # end_date = pd.to_datetime(row['endDate']).strftime('%Y-%m-%dT%H:%M:%S.000Z')

        # Now compare dates in the same format
        if (uploaded['verificationApproach'] == row['verificationApproach'] and
            uploaded['startDate'] == start_date and
            uploaded['verificationBody'] == row['verificationBody'] and
            uploaded['endDate'] == end_date):
            # print(uploaded)

            matched_issuance = uploaded.copy()
            matched_issuance.pop('orgUid', None) 
            return uploaded['id'], matched_issuance
    
        # print(f"No match for row: {row['verificationApproach']} | {row['startDate']} | {row['verificationBody']} | {row['endDate']}")
        # print(f"Compared against: {uploaded['verificationApproach']} | {uploaded['startDate']} | {uploaded['verificationBody']} | {uploaded['endDate']}")
    
    return None,None # Return None or appropriate value if no match found


def merging_issuances_units(df_retired_clean,df_issuances_cleaned,env,outputName):
    merged_issuances_retired_units = pd.merge(df_retired_clean, df_issuances_cleaned, on='id', how='left')
    df_issuances_cleaned_unique = df_issuances_cleaned.drop_duplicates(subset='id')

    duplicates = df_issuances_cleaned_unique.duplicated(subset='id', keep=False)

    # Filter the DataFrame to only include the duplicates
    df_issuances_duplicates = df_issuances_cleaned_unique[duplicates]
    merged_issuances_retired_units.drop('projectId_x', axis=1, inplace=True)

    merged_issuances_retired_units.drop('verificationBody_x', axis=1, inplace=True)
    merged_issuances_retired_units.rename(columns={'projectId_y': 'projectId'}, inplace=True)
    merged_issuances_retired_units.rename(columns={'verificationBody_y': 'verificationBody'}, inplace=True)
    merged_issuances_retired_units['correspondingAdjustmentStatus']= "Not Applicable"


    merged_issuances_retired_units.dropna()

    merged_issuances_retired_units['unitRegistryLink']='https://cdm.unfccc.int/Projects/Validation/DB/' +merged_issuances_retired_units['projectId']+"/view.html"
    merged_issuances_retired_units['warehouseProjectId'] = merged_issuances_retired_units['projectId'].map(project_id_to_warehouseId)
    merged_issuances_retired_units['uploadedIssuance']= merged_issuances_retired_units['projectId'].map(issuance_mapping)
    merged_issuances_retired_units['inCountryJurisdictionOfOwner']= merged_issuances_retired_units['unitOwner']

    merged_issuances_retired_units.rename(columns={'id': 'issuanceOriginalId'}, inplace=True)
    merged_issuances_retired_units['projectLocationId'] = merged_issuances_retired_units['projectId'].map(project_id_to_warehouseId)

    # WARNING JUST FOR THIS TESTNET ONLY YOOO
    if env == "testnet":
        merged_issuances_retired_units = merged_issuances_retired_units.dropna(subset=['uploadedIssuance'])
    if env == "mainnet":
        merged_issuances_retired_units = merged_issuances_retired_units.dropna(subset=['uploadedIssuance'])


    merged_issuances_retired_units[['newId', 'matchedIssuance']] = merged_issuances_retired_units.apply(
        lambda row: match_uploaded_issuance(row), 
        axis=1, 
        result_type='expand'
    )

    null_count = merged_issuances_retired_units['newId'].isna().sum()

    # Print the count
    print(f"The 'newId' column has {null_count} null values.")
    # if env!="testnet" :
    #     assert null_count == 0, f"There are {null_count} null values in the 'newId' column, but there should be none."

    if env=="testnet":
        merged_issuances_retired_units = merged_issuances_retired_units.dropna(subset=['matchedIssuance'])
    if env=="mainnet":
        merged_issuances_retired_units = merged_issuances_retired_units.dropna(subset=['matchedIssuance'])

    merged_issuances_retired_units.drop('projectId', axis=1, inplace=True)
    merged_issuances_retired_units.drop('geographyIdentifier', axis=1, inplace=True)
    merged_issuances_retired_units['unitType']="Not Determined"
    merged_issuances_retired_units.drop('uploadedIssuance', axis=1, inplace=True)
    merged_issuances_retired_units.drop('warehouseProjectId', axis=1, inplace=True)
    columns_to_drop = ['verificationBody', 'startDate', 'endDate', 'verificationReportDate', 'verificationApproach','issuanceOriginalId','newId']

    # Drop the specified columns
    merged_issuances_retired_units = merged_issuances_retired_units.drop(columns=columns_to_drop)
    merged_issuances_retired_units.rename(columns={'matchedIssuance': 'issuance'}, inplace=True)
    merged_issuances_retired_units['unitBlockStart'] = merged_issuances_retired_units['unitBlockStart'].astype(str)
    merged_issuances_retired_units['unitBlockEnd'] = merged_issuances_retired_units['unitBlockEnd'].astype(str)


    merged_issuances_retired_units.to_excel("./output/"+outputName)
    return merged_issuances_retired_units

# uncomment this later
merged_issuances_held_units = merging_issuances_units(df_units_held,df_issuances_cleaned,"testnet","held_units_500_1000.xlsx")
merged_issuances_retired_units = merging_issuances_units(df_retired_clean,df_issuances_cleaned,"testnet","retired_units_500_1000.xlsx")



merged_issuances_held_units = pd.read_excel('cleaned_bef_2016_held.xlsx')
merged_issuances_retired_units = pd.read_excel('cleaned_bef_2016_retired.xlsx')

merged_issuances_held_units.drop('Unnamed: 0.1', axis=1, inplace=True)
merged_issuances_held_units.drop('Unnamed: 0', axis=1, inplace=True)
merged_issuances_retired_units.drop('Unnamed: 0.1', axis=1, inplace=True)
merged_issuances_retired_units.drop('Unnamed: 0', axis=1, inplace=True)






print(len(merged_issuances_retired_units))
print(len(merged_issuances_retired_units['projectLocationId'].unique()))
print(len(merged_issuances_held_units))
print(len(merged_issuances_held_units['projectLocationId'].unique()))


# print(merged_issuances_retired_units['projectLocationId'].unique())



merged_issuances_held_units
# merged_issuances_retired_units
# merged_issuances_retired_units
# Out:
# The 'newId' column has 1 null values.
# The 'newId' column has 0 null values.
# 12826
# 451
# 9293
# 2564
#      unitStatus  unitCount  unitBlockStart  unitBlockEnd     unitOwner  \
# 0          Held     116637       294645211     294761848         India
# 1          Held      66817       321126168     321192985         India
# 2          Held       3250       321122918     321126168         India
# 3          Held      44261       323764558     323808819         India
# 4          Held       6921       323808819     323815740         India
# ...         ...        ...             ...           ...           ...
# 9288       Held      34749         8949478       8984227  South Africa
# 9289       Held     711503      1074008908    1074720411         China
# 9290       Held     653203       195336932     195990135         India
# 9291       Held     369822          119705        489527    Bangladesh
# 9292       Held      28880       279244827     279273707         India
#
#      countryJurisdictionOfOwner inCountryJurisdictionOfOwner  \
# 0                         India                        India
# 1                         India                        India
# 2                         India                        India
# 3                         India                        India
# 4                         India                        India
# ...                         ...                          ...
# 9288               South Africa                 South Africa
# 9289                      China                        China
# 9290                      India                        India
# 9291                 Bangladesh                   Bangladesh
# 9292                      India                        India
#
#                                        unitRegistryLink  \
# 0     https://cdm.unfccc.int/Projects/Validation/DB/...
# 1     https://cdm.unfccc.int/Projects/Validation/DB/...
# 2     https://cdm.unfccc.int/Projects/Validation/DB/...
# 3     https://cdm.unfccc.int/Projects/Validation/DB/...
# 4     https://cdm.unfccc.int/Projects/Validation/DB/...
# ...                                                 ...
# 9288  https://cdm.unfccc.int/Projects/Validation/DB/...
# 9289  https://cdm.unfccc.int/Projects/Validation/DB/...
# 9290  https://cdm.unfccc.int/Projects/Validation/DB/...
# 9291  https://cdm.unfccc.int/Projects/Validation/DB/...
# 9292  https://cdm.unfccc.int/Projects/Validation/DB/...
#
#      correspondingAdjustmentDeclaration        unitType  vintageYear  \
# 0                               Unknown  Not Determined         2015
# 1                               Unknown  Not Determined         2013
# 2                               Unknown  Not Determined         2012
# 3                               Unknown  Not Determined         2013
# 4                               Unknown  Not Determined         2012
# ...                                 ...             ...          ...
# 9288                            Unknown  Not Determined         2012
# 9289                            Unknown  Not Determined         2015
# 9290                            Unknown  Not Determined         2010
# 9291                            Unknown  Not Determined         2013
# 9292                            Unknown  Not Determined         2013
#
#      correspondingAdjustmentStatus                     projectLocationId  \
# 0                   Not Applicable  9da8ba45-4ed8-49de-9dd2-f330f6ba7692
# 1                   Not Applicable  36425802-507d-4f1b-9eb5-35a1db08c555
# 2                   Not Applicable  36425802-507d-4f1b-9eb5-35a1db08c555
# 3                   Not Applicable  b473dbc2-a9d6-417a-b567-5552a88d0b8d
# 4                   Not Applicable  b473dbc2-a9d6-417a-b567-5552a88d0b8d
# ...                            ...                                   ...
# 9288                Not Applicable  571ec6fb-066a-4e17-9d88-0e0cac8dd6c1
# 9289                Not Applicable  d72305f7-ca7c-444a-a94b-80f96b78e403
# 9290                Not Applicable  12276578-2da8-44f2-a6b8-3d0a41df39c4
# 9291                Not Applicable  9c29a8c4-f9de-49c0-83c2-005684722c61
# 9292                Not Applicable  9db5570f-c0de-4cbe-9dde-fbc872dd5ad2
#
#                                                issuance
# 0     {'id': 'b45d627b-ad62-4650-90be-87345324a346',...
# 1     {'id': '82da4b46-3122-4ff4-8d8f-cb61004f9628',...
# 2     {'id': '2cf41405-cccd-44cc-806c-1bc83eeefe73',...
# 3     {'id': 'a73d9683-72a1-4033-9716-2a1fc6e4bbb8',...
# 4     {'id': 'a2d38366-cb3c-4b5c-a27a-30c293f7ab60',...
# ...                                                 ...
# 9288  {'id': 'e22e4d89-17f1-4651-a52a-9573b5f1759c',...
# 9289  {'id': '65dc2788-ea97-4f03-bafc-ffce9d300a5c',...
# 9290  {'id': 'c346febb-a996-4d45-9e42-1358a3366619',...
# 9291  {'id': 'dcb3434e-a554-4b21-ae8b-c1bde73eaa21',...
# 9292  {'id': 'e87c53e9-aed2-4750-87f2-73713368213d',...
#
# [9293 rows x 14 columns]

# %%
# df_units_held


# merged_issuances_held_units = pd.merge(df_units_held, df_issuances_cleaned, on='id', how='left')

# # merged_issuances_units
# df_issuances_cleaned
# df_issuances_cleaned_unique = df_issuances_cleaned.drop_duplicates(subset='id')

# df_issuances_cleaned_unique

# duplicates = df_issuances_cleaned_unique.duplicated(subset='id', keep=False)

# # Filter the DataFrame to only include the duplicates
# df_issuances_duplicates = df_issuances_cleaned_unique[duplicates]

# # df_issuances_duplicates.to_excel("./output/duplicateIssuances.xlsx")

# merged_issuances_held_units .drop('projectId_x', axis=1, inplace=True)

# merged_issuances_held_units.drop('verificationBody_x', axis=1, inplace=True)
# merged_issuances_held_units.rename(columns={'projectId_y': 'projectId'}, inplace=True)
# merged_issuances_held_units.rename(columns={'verificationBody_y': 'verificationBody'}, inplace=True)
# merged_issuances_held_units['correspondingAdjustmentStatus']= "Not Applicable"
# merged_issuances_held_units['correspondingAdjustmentStatus']= "Not Applicable"
# # merged_issuances_units['warehouseProjectId']= merged_issuances_units['projectId'].map(project_to_uuid_map)


# # merged_issuances_held_units.dropna()


# merged_issuances_held_units['unitRegistryLink']='https://cdm.unfccc.int/Projects/Validation/DB/' +merged_issuances_held_units['projectId']+"/view.html"
# merged_issuances_held_units['warehouseProjectId'] = merged_issuances_held_units['projectId'].map(project_id_to_warehouseId)
# merged_issuances_held_units['uploadedIssuance']= merged_issuances_held_units['projectId'].map(issuance_mapping)
# merged_issuances_held_units['inCountryJurisdictionOfOwner']= merged_issuances_held_units['unitOwner']

# # merged_issuances_retired_units['in']= merged_issuances_retired_units['projectId'].map(issuance_mapping)

# merged_issuances_held_units.rename(columns={'id': 'issuanceOriginalId'}, inplace=True)
# merged_issuances_held_units['projectLocationId'] = merged_issuances_held_units['projectId'].map(project_id_to_warehouseId)

# def match_uploaded_issuance(row):
#     for uploaded in row['uploadedIssuance']:

#         start_date = pd.to_datetime(row['startDate']).strftime('%Y-%m-%dT%H:%M:%S.000Z')
#         end_date = pd.to_datetime(row['endDate']).strftime('%Y-%m-%dT%H:%M:%S.000Z')

#         # Now compare dates in the same format
#         if (uploaded['verificationApproach'] == row['verificationApproach'] and
#             uploaded['startDate'] == start_date and
#             uploaded['verificationBody'] == row['verificationBody'] and
#             uploaded['endDate'] == end_date):
#             # print(uploaded)

#             matched_issuance = uploaded.copy()
#             matched_issuance.pop('orgUid', None) 
#             return uploaded['id'], matched_issuance
    
#         # print(f"No match for row: {row['verificationApproach']} | {row['startDate']} | {row['verificationBody']} | {row['endDate']}")
#         # print(f"Compared against: {uploaded['verificationApproach']} | {uploaded['startDate']} | {uploaded['verificationBody']} | {uploaded['endDate']}")
    
#     return None,None # Return None or appropriate value if no match found

# merged_issuances_held_units[['newId', 'matchedIssuance']] = merged_issuances_held_units.apply(
#     lambda row: match_uploaded_issuance(row), 
#     axis=1, 
#     result_type='expand'
# )

# null_count = merged_issuances_held_units['newId'].isna().sum()

# # Print the count
# print(f"The 'newId' column has {null_count} null values.")
# assert null_count == 0, f"There are {null_count} null values in the 'newId' column, but there should be none."


# merged_issuances_held_units.drop('projectId', axis=1, inplace=True)
# merged_issuances_held_units.drop('geographyIdentifier', axis=1, inplace=True)
# merged_issuances_held_units['unitType']="Not Determined"
# merged_issuances_held_units.drop('uploadedIssuance', axis=1, inplace=True)
# merged_issuances_held_units.drop('warehouseProjectId', axis=1, inplace=True)
# columns_to_drop = ['verificationBody', 'startDate', 'endDate', 'verificationReportDate', 'verificationApproach','issuanceOriginalId','newId']

# # Drop the specified columns
# merged_issuances_held_units = merged_issuances_held_units.drop(columns=columns_to_drop)
# merged_issuances_held_units.rename(columns={'matchedIssuance': 'issuance'}, inplace=True)
# merged_issuances_held_units['unitBlockStart'] = merged_issuances_held_units['unitBlockStart'].astype(str)
# merged_issuances_held_units['unitBlockEnd'] = merged_issuances_held_units['unitBlockEnd'].astype(str)




# merged_issuances_held_units.to_excel("./output/held_units_api_upload.xlsx")

# merged_issuances_held_units

# %%
def post_units(df, url, start_index, end_index):
  
    uuids = []
    # Iterate over the specified range of rows
    for i in range(start_index, min(end_index, len(df))):
        row = df.iloc[i]
        data = row.to_dict()
        # this is only bcs after loading fr excel
        if isinstance(data.get('issuance'), str):
            issuance_str = data['issuance'].replace("'", '"').strip()
            issuance_str = issuance_str.replace('None', 'null')
            # print(issuance_str)
            issuance_json = json.loads(issuance_str)
            # print(issuance_json)
            data['issuance'] = issuance_json
        data['unitBlockStart'] = str(data['unitBlockStart'])
        data['unitBlockEnd'] = str(data['unitBlockEnd'])
        
        
        # print(data)
        response = requests.post(url, json=data)

        # print(response)
        try:

            if response.status_code == 200:  # Check if the request was successful
                print("i is",i)
                response_data = response.json()
                uuids.append(response_data.get('uuid'))  # Get the UUID and add to the list
            else:
                    print("i is",i)
                    print(data)
                    print(f"Failed to post project with ID:  {row['issuance']['id']}. Status code: {response.status_code}. Message: {response.json()}")
                    break
            # if type=="update":

            #     response = requests.put(url, json=request_body)
        except RequestException as e:
            print(data)
            print(f"Request failed for project with ID:  {row['issuance']['id']}. Error: {e}")
            break
    return uuids

# Example usage

# %%
url = "http://localhost:31310/v1/units"  # Replace with your actual URL
# start_index = 0# Starting index
# end_index = 500  # Ending index
# rmbr gener 76, 1500-2000, i think then bcs of this generat 76 is 2-2.5k
# 79 was ok i think
# 4kto 5k shld be gen 80
# cancel the 6500 and 7500?

# Call the function with the DataFrame and the specified range
uuids = post_units(merged_issuances_retired_units, url, 0, 1000)
uuids
# Out:
# i is 9000
# i is 9001
# i is 9002
# i is 9003
# i is 9004
# i is 9005
# i is 9006
# i is 9007
# i is 9008
# i is 9009
# i is 9010
# i is 9011
# i is 9012
# i is 9013
# i is 9014
# i is 9015
# i is 9016
# i is 9017
# i is 9018
# i is 9019
# i is 9020
# i is 9021
# i is 9022
# i is 9023
# i is 9024
# i is 9025
# i is 9026
# i is 9027
# i is 9028
# i is 9029
# i is 9030
# i is 9031
# i is 9032
# i is 9033
# i is 9034
# i is 9035
# i is 9036
# i is 9037
# i is 9038
# i is 9039
# i is 9040
# i is 9041
# i is 9042
# i is 9043
# i is 9044
# i is 9045
# i is 9046
# i is 9047
# i is 9048
# i is 9049
# i is 9050
# i is 9051
# i is 9052
# i is 9053
# i is 9054
# i is 9055
# i is 9056
# i is 9057
# i is 9058
# i is 9059
# i is 9060
# i is 9061
# i is 9062
# i is 9063
# i is 9064
# i is 9065
# i is 9066
# i is 9067
# i is 9068
# i is 9069
# i is 9070
# i is 9071
# i is 9072
# i is 9073
# i is 9074
# i is 9075
# i is 9076
# i is 9077
# i is 9078
# i is 9079
# i is 9080
# i is 9081
# i is 9082
# i is 9083
# i is 9084
# i is 9085
# i is 9086
# i is 9087
# i is 9088
# i is 9089
# i is 9090
# i is 9091
# i is 9092
# i is 9093
# i is 9094
# i is 9095
# i is 9096
# i is 9097
# i is 9098
# i is 9099
# i is 9100
# i is 9101
# i is 9102
# i is 9103
# i is 9104
# i is 9105
# i is 9106
# i is 9107
# i is 9108
# i is 9109
# i is 9110
# i is 9111
# i is 9112
# i is 9113
# i is 9114
# i is 9115
# i is 9116
# i is 9117
# i is 9118
# i is 9119
# i is 9120
# i is 9121
# i is 9122
# i is 9123
# i is 9124
# i is 9125
# i is 9126
# i is 9127
# i is 9128
# i is 9129
# i is 9130
# i is 9131
# i is 9132
# i is 9133
# i is 9134
# i is 9135
# i is 9136
# i is 9137
# i is 9138
# i is 9139
# i is 9140
# i is 9141
# i is 9142
# i is 9143
# i is 9144
# i is 9145
# i is 9146
# i is 9147
# i is 9148
# i is 9149
# i is 9150
# i is 9151
# i is 9152
# i is 9153
# i is 9154
# i is 9155
# i is 9156
# i is 9157
# i is 9158
# i is 9159
# i is 9160
# i is 9161
# i is 9162
# i is 9163
# i is 9164
# i is 9165
# i is 9166
# i is 9167
# i is 9168
# i is 9169
# i is 9170
# i is 9171
# i is 9172
# i is 9173
# i is 9174
# i is 9175
# i is 9176
# i is 9177
# i is 9178
# i is 9179
# i is 9180
# i is 9181
# i is 9182
# i is 9183
# i is 9184
# i is 9185
# i is 9186
# i is 9187
# i is 9188
# i is 9189
# i is 9190
# i is 9191
# i is 9192
# i is 9193
# i is 9194
# i is 9195
# i is 9196
# i is 9197
# i is 9198
# i is 9199
# i is 9200
# i is 9201
# i is 9202
# i is 9203
# i is 9204
# i is 9205
# i is 9206
# i is 9207
# i is 9208
# i is 9209
# i is 9210
# i is 9211
# i is 9212
# i is 9213
# i is 9214
# i is 9215
# i is 9216
# i is 9217
# i is 9218
# i is 9219
# i is 9220
# i is 9221
# i is 9222
# i is 9223
# i is 9224
# i is 9225
# i is 9226
# i is 9227
# i is 9228
# i is 9229
# i is 9230
# i is 9231
# i is 9232
# i is 9233
# i is 9234
# i is 9235
# i is 9236
# i is 9237
# i is 9238
# i is 9239
# i is 9240
# i is 9241
# i is 9242
# i is 9243
# i is 9244
# i is 9245
# i is 9246
# i is 9247
# i is 9248
# i is 9249
# i is 9250
# i is 9251
# i is 9252
# i is 9253
# i is 9254
# i is 9255
# i is 9256
# i is 9257
# i is 9258
# i is 9259
# i is 9260
# i is 9261
# i is 9262
# i is 9263
# i is 9264
# i is 9265
# i is 9266
# i is 9267
# i is 9268
# i is 9269
# i is 9270
# i is 9271
# i is 9272
# i is 9273
# i is 9274
# i is 9275
# i is 9276
# i is 9277
# i is 9278
# i is 9279
# i is 9280
# i is 9281
# i is 9282
# i is 9283
# i is 9284
# i is 9285
# i is 9286
# i is 9287
# i is 9288
# i is 9289
# i is 9290
# i is 9291
# i is 9292
# ['2b81438a-5434-420f-915f-660b868c254a',
#  '87fb7013-3ad0-4c66-beb2-9b53dcdc80d0',
#  'd4244129-defc-4f45-a38e-b04715732865',
#  '288fd8e7-6ff1-4989-9470-bb15c7b871bf',
#  'eb259702-9875-4bd7-8682-01a44f585a81',
#  '982539ef-df42-4371-9bc1-067e21776fb9',
#  'c3a21290-a5f6-488c-b8d7-cae90500fa0f',
#  'f34e2c82-ca71-4055-9044-c5cf4392e7be',
#  '7ccd227f-8689-4f99-bc96-961b4dd36b68',
#  '4d973271-bbcd-4b15-9e97-cf2b99709ae8',
#  'b2e56b0e-60f2-472a-ab7d-50e6d81ad498',
#  '75970a4f-45db-49e2-8d33-695fee6cb8d2',
#  '99b1afcc-5f95-410e-aeae-44952174c918',
#  '4cff3c87-8ba3-43bd-8d5d-e81bedc53e8b',
#  '1f99fdea-4340-43c8-9ac2-bde472e01ffc',
#  '3535dea6-e823-4da2-8d7a-d12f4188c350',
#  'ae0e97b7-68ed-4055-90c5-3abf152c0449',
#  'e1d490c3-030e-4884-96b3-e03dba3ec912',
#  '15946165-9243-4c19-9aa4-01c388085dd0',
#  'd5ec21e1-2023-42c2-b96b-719054df32e4',
#  'dda17f32-b265-4691-8b85-5cbdc078ff27',
#  '0a509c8c-0beb-465f-a13d-e153d46c9b93',
#  'c9540c33-37b2-4020-afbd-d2f4ca032b15',
#  'dfcb6d5f-9baf-41ab-b782-89cc5acd6ad4',
#  '20bd6625-528e-4d03-a06e-ec6d6cd0effd',
#  '96768abe-23ea-4e7b-bacd-5535c175f63d',
#  '35243f07-031e-4d7c-8129-772a603f9fec',
#  '1eb4e098-126e-4ac3-89da-34e25ba992ed',
#  '3a3e368a-ac35-46ec-8683-5142589552ee',
#  '2708e010-097e-4160-85aa-50b10c60b74e',
#  '19e54656-11c8-4e61-a111-f9ae11ebfe86',
#  '5486960c-8234-40f7-8eab-ab90860ba549',
#  'bcb0ef9f-ea5f-49b1-a311-d155cff875d0',
#  '040aef94-8fcf-4a27-8018-56b19b5255e3',
#  '950f03f1-15ea-4aeb-b7fb-823d2b73579f',
#  '1160a7d1-4cda-4572-88dd-44e5766449c2',
#  '9c81198f-2ce8-4f1c-818a-4484c281cdfc',
#  'c3136676-0c56-45d9-a69a-0b07b2705028',
#  '548d721b-b3cc-47ab-b6ef-23437c2e7336',
#  '0030db27-f0ba-42bd-bea1-4477f7ea2641',
#  'bee9d0b0-68e8-4ed8-8b4c-d536986ba4bf',
#  'b1ddd347-6059-4f73-9eed-b41430cdf3ee',
#  '1a09f9db-e66f-436b-bdb3-5f1447640787',
#  '94d5f664-01e8-42d1-bcc6-b300b0fe35ea',
#  'e45fe616-56c8-41b4-9c0a-54fc4dcada56',
#  '4a3406e6-9298-46ba-8b0e-8b8fa49ea404',
#  '74cb4302-5931-482c-b21a-f8d2565d4d26',
#  'aab16096-0780-479a-bc71-d67795f7aadd',
#  'edd12ee7-f3f0-4903-9044-2e48c4a836ca',
#  '53e88a5b-4196-4025-aeef-ddaa6c2d52b4',
#  'b56a7a80-d675-4b4b-8cbe-d3792b27cfca',
#  '89123eb1-125e-436e-9a31-8be77752a1d5',
#  '0a9fc813-d29d-4934-a096-83459cb934e5',
#  '6700d7a7-09db-4fc7-97d5-edd49918d2a1',
#  '99edbf67-8cac-4e4e-8ff4-9d449f42112d',
#  '211c9bf3-de04-415c-86ef-f2c5a1f4360b',
#  '0e8ae0a1-177b-49b6-b5b9-b6fbf0c22434',
#  'fcca9eff-3e95-49a9-868d-e0a5e4ab359d',
#  'f1b6b142-fdd2-4df6-be3a-8623a5fee217',
#  '46ba1627-a3eb-4fd5-944b-64cccbd8ebce',
#  '7fbc61f7-9586-49a1-933e-2b6e302d9432',
#  '75572a86-9712-47d2-be65-d0b211d9cab3',
#  'a586155a-00b4-407a-adcb-f2f7963bbedf',
#  '3b83bf75-be2e-4186-95bb-ef858e0e0e4f',
#  'a9cd2924-96e9-4317-bdfa-d136d84a108e',
#  '6a39db63-0e4d-4883-b93f-bdd9464389a0',
#  'ba97fc44-fe2d-47b8-bf9c-4f73709bc87b',
#  '47cc7f7a-4447-48f4-896d-590f22aa9bb5',
#  'fea67aed-bcaa-4f71-84a0-fd400ba71783',
#  'e607bc13-76df-4246-844e-2d89d10827d1',
#  '28325b1a-3fbb-4280-b2c9-e37497683777',
#  '6735b516-d224-48d1-8a91-9c3111295a6b',
#  '0920c137-0d88-41f0-8cca-fa86e5e0ce2e',
#  '3b6e87e6-b1b5-43ab-b7b9-ca605b6ea509',
#  '4966d491-e925-4b4f-871c-ff7b24cd91bd',
#  '766451b7-e576-4294-ac0c-d00472c0997d',
#  '5998de65-cf11-41c0-a926-ba8a4934621c',
#  'b04c33f6-beef-42d6-b844-16c5c163cb2f',
#  '77da86c3-d48a-4133-915e-4297215bbe83',
#  '98e978b3-8efe-4109-b284-ecf21445185c',
#  '709eb3ae-4319-4e96-bb4a-05613b42b1b8',
#  '9f4ea6b5-04f5-4f44-80b6-e729195785cc',
#  'cbd8d6aa-556b-4a2c-805e-3e445442ad70',
#  '2cf20078-ce41-496c-9d23-140aa6c8dcfa',
#  '60b2157c-6f00-482e-881c-e3aa1662f439',
#  'cae967cc-bf69-4aa7-adf7-0af79b5b5106',
#  'ef6b4dd4-f264-42ee-a9a4-271deb4bc248',
#  '7bef9e1e-5ed7-4f6e-a1d1-4e4c76d0b0c7',
#  'a211a382-2d92-40ca-9b7b-661f656b93c4',
#  '7e8f4fff-487b-4653-b3d6-a74c94fb1754',
#  '84a352eb-98bc-4091-b848-8a8d4f41ebf7',
#  '60738c02-1fc9-4f1b-a286-3447695cd952',
#  '5f9ad282-c56c-4a50-81b0-ed331efa0c40',
#  '57d681f4-d49b-4341-800d-e60633ce5f50',
#  '4068df57-43b8-449d-82ca-6070c47d2790',
#  'ba8935f9-2282-4122-8f29-5b26cc71b740',
#  '2c5b6c69-b64a-4dd9-921c-adab961ca294',
#  '046c676e-ae9a-468b-9a7e-04dd836e4df2',
#  'def4fd21-8cea-4003-9b80-887242a4ca05',
#  '0a4249ba-9318-4063-ba74-b0736ef32578',
#  '321922a4-e04c-415b-bf27-ab4f41776f95',
#  '7491f701-a5c9-4816-b143-20ef02e6b21a',
#  '95e2ad80-2408-4278-a1c1-328733f943d8',
#  '6b0d28b7-cd2c-4eb5-b19a-10b8a2f4f415',
#  '71b1984b-80a3-4862-8632-ac6adca3bc6f',
#  '247e8cfa-91c8-4fab-a63b-08100d1bcc1b',
#  'c7e25f84-63da-494e-9c49-57ad2d53bfba',
#  'add80836-45fc-4dfa-b8d2-f44239871623',
#  'ddbe0a5a-84e8-4d33-9818-b5b75a813859',
#  '4397b394-45ef-4857-9413-25dd936d10ee',
#  '225984d4-b402-409c-a2ce-084c6487d306',
#  'b9eda9b3-d6df-41c1-9583-84e6d53e145b',
#  'e5db3f03-2697-42ce-9ee7-5bbf5af75073',
#  '9aa7d22e-fc8e-4d5e-8a59-0509e71f9064',
#  'f6ffd223-e9dd-4e6d-b9d9-dd06f409cc9e',
#  'edb93bc9-5a49-4bd6-8437-41d875196f6b',
#  'd9bf075b-db0a-436b-bd23-8bd805d25865',
#  'ddd01fd5-71ba-4cee-9ecc-7b36d5dd9c6f',
#  'eef04b68-b521-4620-b491-9f00ae00abc3',
#  'bc3a68cc-c7a9-42f8-baaf-a2c3a44ba51a',
#  '8265abc9-a123-49e7-ae77-a5866e0dfc45',
#  'b4dca35a-6198-40ab-9c06-a6b4ecf7b298',
#  'a1794f1f-c566-4c0b-b207-04a8257501bf',
#  '39c67d6c-64a8-49bd-954c-87856514a1e4',
#  'e5c490a3-b806-4186-a31d-9e38a5ceaaf7',
#  'dbdc00f4-86e5-4d1d-97e5-78406dca2b9f',
#  '5a275f5c-b091-4859-bf3e-3eeb76b38afc',
#  'c359727e-ac42-44a4-a0c2-e623eedcae94',
#  '07f0d8f0-ba91-4599-a261-71c5672a8230',
#  '37dd2d9e-1a2a-4a13-bc12-4d083184e8e2',
#  '8fcbc2fb-e922-48f9-bd4f-df71858b8dd8',
#  '2d5378f1-d633-4a2f-9298-ebcdebcd663c',
#  'dfc00e79-6c29-409d-ae7a-ff6a35de48c6',
#  '4b1b1e60-7fb3-44db-8060-0ec7da8c60ad',
#  'bd56a67e-4e80-42a2-ad9c-5999e4f4b14e',
#  'b909810f-220f-44a8-9d5e-229246fa65a8',
#  '28a3444d-f4a9-4395-81be-788ab21f75c8',
#  'f697a38d-8fe2-4c1f-968d-186ebde31724',
#  'ede119d0-b1af-47e9-91f1-9cc098cf6f17',
#  '279e0f98-7564-482e-9d62-3c285922d0d4',
#  '698815a6-dadc-40c7-90b1-279bbb8c29c8',
#  '4f8eedbe-219d-45ce-9d59-c698e556b226',
#  '7421e519-4af4-4492-9163-0b94d2e74483',
#  'f9dcaf62-b316-42db-8214-1fdb363c4f54',
#  '81c4100d-d982-4176-8e53-574c2e31f9bf',
#  'd1e5145a-76ce-4cbf-bccc-1aa59cc3c3dd',
#  'd1eea953-0e9f-44ca-9cfb-c0ebc7b13352',
#  'e12f7e2d-212b-4f37-b9ff-de81f75363b7',
#  '32a3bffc-1ada-4c68-aa05-0ea80f96db95',
#  '14ad5b50-ca14-4fd7-8939-9a056105a34b',
#  '8af05694-431f-4fe6-8015-acebb3193b37',
#  '26757fb8-b5b1-4c6e-8bae-7e6738428257',
#  '4a26ca8b-d3d9-49a4-994c-98e7c4c5b682',
#  '4c84441b-3e74-451b-8445-4d5b1c9fd1df',
#  '5dfb8369-0aeb-4d0d-916e-650772ab6aaf',
#  '98ac8f90-830d-4eff-807e-04db11db5faa',
#  '73f0e297-448d-48e1-a49e-25cbaaa9f6d6',
#  'e2b73c25-345a-4271-8eeb-d0f73710e15f',
#  'dd93cc0a-036e-468f-8702-ba12e6023267',
#  '24bc1ddf-6238-4e8e-8fb0-a88ac89aa341',
#  '3e0dffac-2a95-4ae4-be08-01e30e9bf71b',
#  '10691f6c-64bd-4b9b-82e2-d2413d4b4d6e',
#  '7934d0ff-9df3-4c4e-a97f-62e909fd9ee1',
#  '5f68866e-b4b4-4596-8c87-4bcfd78e7f25',
#  'a7c03c7d-527b-43c1-9025-7729d71e0130',
#  '6e59676d-577a-4acc-9128-51a639db2e3c',
#  '1d1cf72c-627d-430b-b044-3a3f36f931ac',
#  'de3b729b-b8e5-4527-88ab-8af5575a747d',
#  '0a849aa8-5cd1-442f-ba1e-775f95783299',
#  'b1d89263-1ae7-4caf-b536-33d80811c4c7',
#  'afecf6d2-4f56-4a08-b7d0-29cc317a7fce',
#  'd3ab801a-c275-474b-aeaf-ba1c02c22ac6',
#  'a6987fe2-0b5b-41cd-a36a-60230ee40b14',
#  '2a97ccac-6671-4166-9310-89036ad9ccf4',
#  'c20d873c-6bc3-411f-a478-45328214a7d9',
#  '136b7b45-338b-4a12-80ce-e8dfbfb01b75',
#  'cb16d54d-ddfb-4e65-8674-2a8a32be30ed',
#  '6cf3a956-2e69-41d2-b8c1-3519bd57aa36',
#  '26d9cd6a-fd61-44f1-adac-ccfae57b01b4',
#  'e88ecf1c-9c28-45bf-bf43-941d358818bf',
#  '2be775e7-6294-413e-8d01-277a261ca407',
#  '34cad786-1bd7-4a54-9934-f07bac2ae8e5',
#  'd98a08ff-1e84-43a2-80bb-d3a946a48700',
#  '0f637b52-93d5-49f9-b420-8d8a51334d05',
#  '12aea984-6ee1-4d40-a24b-2817ecd441ed',
#  '54f97346-0a36-47b5-b520-6c96d55e371a',
#  '98dbfecf-0aed-4419-811c-9dc79facdb36',
#  '6214011b-b90f-45df-871e-5309408b717d',
#  'e05c527a-2975-4d7b-80d1-baa718f0ad0a',
#  'ca0f99f9-325b-4971-8cdf-b05b2c3cc19a',
#  '4a4ed2db-ff24-4ef3-92c2-0617d5eba6c9',
#  'e69aa548-3a5f-4da1-8498-e93d2dd87f03',
#  'e46a4b0e-c38a-4339-b9c2-b906b10de849',
#  '88e274a5-9c4f-42d1-b383-2c95fd79d17b',
#  '8c391ba0-ee50-4f5f-818d-c5cb1b327690',
#  '2369be4f-58ae-4387-a88a-904609d0f6bf',
#  'ae8fb639-1979-4d65-8b4b-be5225a878ae',
#  '48e192b1-cb0a-46d6-a1ca-361482bde3c5',
#  'ae75a7eb-b735-4ccb-904e-63050b562c76',
#  '968a2eba-5466-4a32-938e-fb858c59e7e7',
#  '35f02513-5f6a-4afa-b66b-3751f8a8077e',
#  '364e4fba-c66f-41a2-a4c3-ceab39c7e060',
#  '38be63da-7e1b-4e1f-a16e-7b03237f5f7d',
#  'b61d5962-7be1-4b68-aaac-9a40764cf792',
#  '315c9e16-c124-4d60-9475-0db30c4028d5',
#  'e65f2750-5162-47d4-b6b3-aedd92b2985f',
#  '75421261-2efc-4d81-b6e6-09be9b9939ec',
#  '691d4a94-bdd9-4b4a-b45e-c1878d83cb1e',
#  '49331d28-1448-45e9-b9c4-8aa9c9fd5211',
#  '2dbf876d-1840-4228-9d09-4672ad5e8d1d',
#  '024e0b0c-f23c-4629-9da9-501297040ccb',
#  '2bef7511-b5d8-4d4c-855f-90e0b8bb8356',
#  '64af4f8a-688a-47ae-b826-6150b83bba0c',
#  'cba3f846-8216-4492-abfe-0a3e0e654d38',
#  '24dd987f-92a9-4524-bf03-184db6fa069f',
#  'd628a4d8-81c6-42b7-8977-374ef44da677',
#  '275c727c-78c5-42f6-83f8-48d9a6e81a79',
#  'aefcad0a-561a-4acd-94aa-4dfadf74b237',
#  '5f35d476-fd5e-4d1b-8f44-b2f584e7b403',
#  '5065322c-7eea-4811-88fb-42500e712942',
#  'de6dcdae-1fde-40f3-b53f-9c1fad132dfb',
#  'e7b8641f-fc61-4bc8-bea1-61f84a0d4c5c',
#  '3dc2857d-c905-41ce-bafe-29562d66fb75',
#  '1e5edb34-39c2-4a25-aef3-94cc3cb8ca4d',
#  'dcd28f35-6ba8-49ba-aa96-d1036409a058',
#  '8e4b9f90-7767-48fc-a9f9-94128b963f13',
#  '43520f4f-2b9b-4904-8f59-dddcc3ba9cce',
#  '647c469a-b487-43e7-8945-fa184ad491de',
#  '3ca883bf-a1ef-4eb4-abb0-d1dc69d7e633',
#  'c0930f03-a78f-4b0c-bde1-1d50b6d13f18',
#  'c45ff8f7-9182-4ca1-bcff-3587ab5de5c5',
#  '1f3fcc23-dddf-464d-a827-22add739e062',
#  'c320f0f0-68c9-4b4c-92f2-c6304261380f',
#  '03ec4eba-1d8e-459c-870f-092a87033b9b',
#  'd6eba59d-3fa0-438c-a214-b163354f8946',
#  '9aecb7de-61ad-4ad5-9bb6-bd661d715b47',
#  '0de3415e-c13f-4492-ac45-bbaec387785c',
#  '388028a8-1d10-459e-b8e0-d79a5a101baa',
#  '2a7a871b-f064-46c6-9501-91f5329a3986',
#  'e257e189-3f97-4c95-995e-e7652fa1939f',
#  '0d084c98-423d-4242-932b-262d7bd847cc',
#  '8c0c2857-17a0-435f-acf2-f2f8d9725682',
#  'a384fe2f-c7f6-4ddc-8c30-376dc72b8d17',
#  '30533b3f-13ac-4ded-bfde-a485becb7dc0',
#  'f4d29718-f28f-42d4-b65a-92a401f46937',
#  'be5a8589-09a1-456e-8869-d7d4af1b0bc7',
#  '932c7f54-98d1-4998-ab4e-fba1275aa74b',
#  'ae4ddf4b-214e-4c87-bc2f-2a6018f77dd5',
#  '8c3c6df0-231f-4ea6-b2a2-eb85dadff685',
#  '9f4429a0-6ab7-4258-be3e-cc80afeafc97',
#  '7ef53a46-4799-43d1-8e6d-0abff6e19139',
#  '1cb2e5e5-832d-4000-8e52-897c60b596c6',
#  '867f1fd7-c7f3-4cdc-a737-890415301a13',
#  'f6aff21b-0a43-4a34-b0da-03a9aa91b7af',
#  'c056082e-7c01-4c03-a82f-96b61344b7e1',
#  '3b27b2c4-d7db-44dc-a097-9bf5e80f8d07',
#  '838431ef-a8be-468b-95ac-ffc701abe8a3',
#  'e9072a33-1c89-424a-9ec1-a3a913d59085',
#  'ced85f35-c8b2-466e-a91d-1d98010e69a4',
#  '9b039350-c0a8-42b1-b8d0-12509680d186',
#  '3aa73c5b-32e5-44f0-972a-64072d1e73b3',
#  'a91361de-a65d-4282-8fce-b8c9d3906025',
#  'eee16234-e312-4fa5-8f4f-6dd5a07c9388',
#  'b1919131-11a6-41a5-bd42-3ec0e7146d61',
#  'ee3392dc-6668-4bc8-8536-f621ae6f224e',
#  '51ed1b9a-1477-4be8-8b2d-371a66512628',
#  '1a9e3b0b-212b-4724-b344-6cc7461705b0',
#  '75f1545d-ed83-473c-a163-0ee701870401',
#  '27f33ca7-99ba-4ae1-a97a-4e7ef9272535',
#  '339171c6-1016-42a7-bc86-af78ead4096c',
#  'b7a08a47-da84-44a2-bbb2-a346612ee3e8',
#  'f0d546b7-2b98-4603-b42a-b2ed6efe7906',
#  '8dd47dd9-66c4-444e-99db-c50e58b1cf4d',
#  'aa01ea33-6686-46b8-870f-8a48aca08a02',
#  '8d032212-0a88-43ef-9045-c851503eb1ab',
#  '25da5f0c-2fc1-4c5e-8b4b-63637c369d31',
#  '4a225935-03af-47e6-b70c-b633316bc1cb',
#  '8e0076a3-e2f4-4d2c-ade7-5b300be6b3e8',
#  '7d281c9c-c572-4744-9d12-cd4174d33313',
#  '1f85cdc4-c171-4705-b30b-29a8502b6e49',
#  '482648a9-4b7a-4a70-9747-27a25e2bcf69',
#  '5040eeea-8f4c-4aad-bb01-18dd18ecdbee',
#  '67d291b9-6d16-4ce1-ac6a-3c90efa0312c',
#  '2d43516b-c136-4177-a2e3-15935f62e9eb',
#  'e1eb5561-c6b6-4603-944b-d706bbb1b428',
#  '0516a8ae-109d-43e1-8a20-78056fd4b134',
#  '43b62767-96c9-410f-94d8-5cb533b5fd26',
#  '3431fb17-9fec-40ec-b5bd-33766a585259',
#  '739bad2c-537d-4115-a172-e52040d226e0',
#  'a0fdfb46-b77f-446a-bdbc-eb487d9ec41c',
#  '0b271348-4a51-4521-b122-4d6f8c966dde',
#  '62b4c453-fbce-4191-999f-b35c1fd6ec40',
#  'e7211de6-e81b-49f5-96ac-2d00a62bd922']

# %% [markdown]
# <!-- 11530 retired units -->

# %%
df_checking_iss = pd.read_excel("./input/CDM-Issuances-November.xlsx")

df_checking_iss

duplic = df_checking_iss.duplicated(subset='Issuance process ID', keep=False)

# Filter the DataFrame to only include the duplicates
df_duplic = df_checking_iss[duplic]
df_duplic = df_duplic.sort_values(by='CDM project reference number', ascending=True)

df_duplic.to_excel("duplicduplic.xlsx")

len(df_checking_iss)
# Out:
# 12548

# %%
def rename_duplicates(df, column_name):
   
    df_copy = df.copy()
    duplic = df_copy.duplicated(subset=column_name, keep=False)
    duplicates = df_copy[duplic].copy()
    duplicates['dup_count'] = duplicates.groupby(column_name).cumcount() + 1
    duplicates[column_name] = duplicates[column_name].astype(str) + '-' + duplicates['dup_count'].astype(str)
    duplicates.drop('dup_count', axis=1, inplace=True)
    df_copy.update(duplicates)
    return df_copy
updated_df = rename_duplicates(df_checking_iss, 'Issuance process ID')
updated_df

# %%
# {
#     "message": "Data Validation error",
#     "errors": [
#         "\"inCountryJurisdictionOfOwner\" is not allowed to be empty",
#         "\"unitBlockStart\" must be a string",
#         "\"unitBlockEnd\" must be a string",
#         "\"unitType\" is not allowed to be empty",
#         "\"issuance.orgUid\" is not allowed",
#         "\"verificationBody\" is not allowed"
#     ],
#     "success": false
# }
# Out:
#                       originProjectId  \
# 24     51Z7LD1J86IUVYIUFF42N3NZ6F6NOB
# 2254   1QA3P4SHFQ3HT5A1PADQD59FL9SPOC
# 7755   U18YV4JT0CQTF3G0LQ0I4FDSCSQM2L
# 8406   RAF02M1RO8Q7V2WW1RPI9ZB6U3QWM2
# 8662   AV4D7HV34I0UH7WJ6S2G3UV9LA2KQV
# 8977   976VA2GJENO0ZMVYWRQJ8XOPG2JXB5
# 9077   Z2GXVTKHQJ8VB82DHT5I70LG7DMABM
# 12038  YDCO88MCSYRWQVM9SXIAN4ZVD0TFF0
#
#                                              projectName program  \
# 24               e7 Bhutan Micro Hydro Power CDM Project      PA
# 2254                 Dagachhu Hydropower Project, Bhutan      PA
# 7755       Punatsangchhu-I Hydroelectric Project, Bhutan      PA
# 8406   Rural Electrification Project for Clean Energy...      PA
# 8662          Mangdechhu Hydroelectric Project Authority      PA
# 8977    Punatsangchhu-II Hydroelectric Project (1020 MW)      PA
# 9077   Substitution of grid power generation through ...      PA
# 12038                Dagachhu Hydropower Project, Bhutan      PA
#
#                                                   sector          projectType  \
# 24     Energy industries (renewable - / non-renewable...                Hydro
# 2254   Energy industries (renewable - / non-renewable...                Hydro
# 7755   Energy industries (renewable - / non-renewable...                Hydro
# 8406                                 Energy distribution  Energy distribution
# 8662   Energy industries (renewable - / non-renewable...                Hydro
# 8977   Energy industries (renewable - / non-renewable...                Hydro
# 9077   Energy industries (renewable - / non-renewable...                Hydro
# 12038  Energy industries (renewable - / non-renewable...                Hydro
#
#       projectStatus        methodology  \
# 24       Registered     CDM - AMS-I.A.
# 2254     Registered      CDM - ACM0002
# 7755     Registered      CDM - ACM0002
# 8406     Registered  CDM - AMS-III.AW.
# 8662     Registered      CDM - ACM0002
# 8977      Validated      CDM - ACM0002
# 9077      Withdrawn      CDM - ACM0002
# 12038     Validated      CDM - ACM0002
#
#                                         validationBody       validationDate  \
# 24                                   JACO CDM CO., LTD  2004-06-04 00:00:00
# 2254                           Det Norske Veritas- CUK  2008-09-03 00:00:00
# 7755   Bureau Veritas Certification Holding SAS (BVCH)  2010-11-04 00:00:00
# 8406                                        RWTÜV GmbH  2013-01-22 00:00:00
# 8662   Bureau Veritas Certification Holding SAS (BVCH)  2014-06-26 00:00:00
# 8977   Bureau Veritas Certification Holding SAS (BVCH)  2014-06-26 00:00:00
# 9077                           Det Norske Veritas- CUK  2007-12-22 00:00:00
# 12038                          Det Norske Veritas- CUK  2007-10-23 00:00:00
#
#       inCountryRegion  ... registryOfOrigin unitMetric  \
# 24      Southern Asia  ...     CDM Registry      tCO2e
# 2254    Southern Asia  ...     CDM Registry      tCO2e
# 7755    Southern Asia  ...     CDM Registry      tCO2e
# 8406    Southern Asia  ...     CDM Registry      tCO2e
# 8662    Southern Asia  ...     CDM Registry      tCO2e
# 8977    Southern Asia  ...     CDM Registry      tCO2e
# 9077    Southern Asia  ...     CDM Registry      tCO2e
# 12038   Southern Asia  ...     CDM Registry      tCO2e
#
#                   projectLink                       projectId coveredByNDC  \
# 24     https://cdm.unfccc.int  51Z7LD1J86IUVYIUFF42N3NZ6F6NOB      Unknown
# 2254   https://cdm.unfccc.int  1QA3P4SHFQ3HT5A1PADQD59FL9SPOC      Unknown
# 7755   https://cdm.unfccc.int  U18YV4JT0CQTF3G0LQ0I4FDSCSQM2L      Unknown
# 8406   https://cdm.unfccc.int  RAF02M1RO8Q7V2WW1RPI9ZB6U3QWM2      Unknown
# 8662   https://cdm.unfccc.int  AV4D7HV34I0UH7WJ6S2G3UV9LA2KQV      Unknown
# 8977   https://cdm.unfccc.int  976VA2GJENO0ZMVYWRQJ8XOPG2JXB5      Unknown
# 9077   https://cdm.unfccc.int  Z2GXVTKHQJ8VB82DHT5I70LG7DMABM      Unknown
# 12038  https://cdm.unfccc.int  YDCO88MCSYRWQVM9SXIAN4ZVD0TFF0      Unknown
#
#       projectStatusDate                                   projectDeveloper  \
# 24           2023-12-08                                E7, Kansai Electric
# 2254         2023-12-08                                       Pöyry Energy
# 7755         2023-12-08                                               PHPA
# 8406         2023-12-08                                               n.a.
# 8662         2023-12-08                                               n.a.
# 8977         2023-12-08                                               n.a.
# 9077         2023-12-08                    Power Grid Corporation of India
# 12038        2023-12-08  Caspervandertak, Gansu Tonghe Investment Proje...
#
#                                geographicIdentifier  \
# 24     {"latitude":27.514162,"longitude":90.433601}
# 2254   {"latitude":27.514162,"longitude":90.433601}
# 7755   {"latitude":27.514162,"longitude":90.433601}
# 8406   {"latitude":27.514162,"longitude":90.433601}
# 8662   {"latitude":27.514162,"longitude":90.433601}
# 8977   {"latitude":27.514162,"longitude":90.433601}
# 9077   {"latitude":27.514162,"longitude":90.433601}
# 12038  {"latitude":27.514162,"longitude":90.433601}
#
#                                              description ndcInformation
# 24               e7 Bhutan Micro Hydro Power CDM Project             NA
# 2254                 Dagachhu Hydropower Project, Bhutan             NA
# 7755       Punatsangchhu-I Hydroelectric Project, Bhutan             NA
# 8406   Rural Electrification Project for Clean Energy...             NA
# 8662          Mangdechhu Hydroelectric Project Authority             NA
# 8977    Punatsangchhu-II Hydroelectric Project (1020 MW)             NA
# 9077   Substitution of grid power generation through ...             NA
# 12038                Dagachhu Hydropower Project, Bhutan             NA
#
# [8 rows x 21 columns]
